# %% [markdown]
# # Extraer datos de WEB
#
# Este Script se concentra en extraer la informacion y datos de la galeria del museo Van Gogh y las cartas escritas por el mismo artista para guardar los archivos de texto, png y otros datos necesarios para crear el set de datos de entrenamiento para un modelo de Machine Larning. Se utiliza BeautifulSoup para extraer la informacion desde los portales WEB de interes
#
# ## Objetivos
#
# Extraer las imagenes, datos y metadatos de cada elemento dentro de la coleccion del museoVan Gogh.
#
# ## Fuente de Datos
#
# Las fuentes de datos para el conjunto de datos son:
#
# * Galeria de obras y trabajo de Van Gogh: https://vangoghmuseum.nl/en/search/collection?q=&artist=Vincent%20van%20Gogh
# * Archivo de cartas escritas por Van Gogh: http://vangoghletters.org/vg/search/simple?term=
# * Ruta de carpetas de recursos de las cartas escritas por Van Gogh: http://vangoghletters.org/vg/letters/

# %%
# importar librerias necesarias para scrapyWEB
import re
import os
import copy
import json
import urllib
import requests
import validators
import datetime
from urllib.parse import urlparse
from bs4 import BeautifulSoup

# importar librerias para hacer un dataframe de referencia
import numpy as np
import pandas as pd
import pandas_profiling as profile

# %% [markdown]
# ## Galeria de Obras de vangoghmuseum.nl

# %% [markdown]
# ### Procesamiento de las pinturas en la galeria
#
# el proceso sigue los siguientes pasos, para facilidad de la estructura se propone un formato JSON por cada uno de los frames que se desean guardar en formato TXT, al final cada carpeta debe tener 4 archivos TXT mas una imagen en formato PNG. Los pasos a seguir son los siguientes:
#
# * Chequeo que los enlaces existan y creo las carpetas necesarias.
# * Extraigo las anotaciones de busqueda cada uno de los elementos de la galeria desde el objeto "Search in the collection:".
# * Extraigo los datos archivisticos de cada elemento de la galeria desde el objeto "OBJECT DATA".
# * Extraigo los trabajos relacionados si existen de cada elemento de la galeria desde el objeto "Related work".
# * Extraigo la imagen en formato PNG de cada elemento de la galeria en el desde el objeto "DOWNLOAD IMAGE"
#
#
# #### Enlaces utiles para el proceso
#
# - Extract links from webpage (BeautifulSoup): https://pythonspot.com/extract-links-from-webpage-beautifulsoup/
# - How to: Find all tags with some given name and attributes: https://kite.com/python/examples/1734/beautifulsoup-find-all-tags-with-some-given-name-and-attributes
# - Beautiful Soup can't find the part of the HTML I want: https://stackoverflow.com/questions/51982930/beautiful-soup-cant-find-the-part-of-the-html-i-want
# - Como chequear que un enlace esta vivo: https://stackoverflow.com/questions/51639585/checking-if-a-website-exist-with-python3
# - Como utilizar libreria Request y el metodo GET: https://realpython.com/python-requests/
# - Manejo de errores en Python 3 URL 1: https://www.python-course.eu/python3_exception_handling.php
# - Manejo de errores en Python 3 URL 2: https://www.tutorialspoint.com/python3/python_exceptions.htm
# - Descargar una imagen desde un URL: https://stackabuse.com/download-files-with-python/
# - Reconocer si un string es un URL valido URL 1: https://stackoverflow.com/questions/7160737/python-how-to-validate-a-url-in-python-malformed-or-not
# - Reconocer si un string es un URL valido URL 2: https://www.codespeedy.com/check-if-a-string-is-a-valid-url-or-not-in-python/
# - Reconocer si un string tiene un substring importante URL: https://stackoverflow.com/questions/50432978/find-substring-of-keyword-using-beautifulsoup
# - Remplazar signos de puntuacion entre palabras por espacios URL: https://stackoverflow.com/questions/44263446/python-regex-to-add-space-after-dot-or-comma
# - Como guardar un archivo JSON en Python: https://stackoverflow.com/questions/12309269/how-do-i-write-json-data-to-a-file
# - Recomendaciones de uso del JSON en Python: https://stackabuse.com/reading-and-writing-json-to-a-file-in-python/
# - Como actualizar un dataframe con informacion de otro: https://stackoverflow.com/questions/49928463/python-pandas-update-a-dataframe-value-from-another-dataframe

# %% [markdown]
# ### Definicion del DataFrame para la galeria
# defino las columnas necesarias del DataFrame para saber que he podido recuperar y que no, TRUE es que si lo tengo, FALSE de lo contrario

# %%
# lista de columnas para trabajar el DataFrame de la galeria, sirve para manejar la calidad del proceso
# conocer los errores y ver que datos faltan por cada elemento de la galeria
soupCol = [
    "ID", # identificador unico de la galeria, tambien es el nombre del folder dentro del directorio local
    "NAME", # nombre del elemento en la galeria
    "ELEMENT_URL", # enlace del elemento recuperado del ScrapyWEB
    "DOWNLOAD_URL", # enlace de la imagen dentro del elemento de la galeria

    "HAS_ID", # booleano que identifica si se tiene un folder local del elemento
    "HAS_NAME", # booleano que identifica si se tiene el nombre del elemento
    
    "HAS_DESCRIPTION", # booleano que identifica si se tiene la seccion de descripcion en el HTML del elemento
    "HAS_DOWNLOAD", # booleano que identifica si se tiene la seccion de enlace de descarga en el HTML del elemento
    "HAS_TAGS", # booleano que identifica si se tiene la seccion de tags de busqueda en el HTML del elemento
    "HAS_DATA", # booleano que identifica si se tiene la seccion de datos de archivo en el HTML del elemento
    "HAS_RELATEDW", # booleano que identifica si se tiene la seccion de trabajo relacionado en el HTML del elemento
    
    "ERR_ID", # si no se puede crear la carpeta con el ID se guarda el error aca
    "ERR_NAME", # si no se obtiene el nombre se guarda el error aca
    
    "ERR_DESCRIPTION", # si no se obtiene la descripcion se guarda el error aca 
    "ERR_DOWNLOAD", # si no se obtiene el enlace de descarga se guarda el error aca 
    "ERR_TAGS", # si no se obtiene los tags de busqueda se guarda el error aca 
    "ERR_DATA", # si no se obtiene los datos de archivo se guarda el error aca 
    "ERR_RELATEDW", # si no se obtiene el trabajo relacionado se guarda el error aca 
    
    "DESCRIPTION", # aqui guardo el JSON con la informacion de la descripcion
    "TAGS", # aqui guardo el JSON con la informacion de los tags de busqueda
    "DATA", # aqui guardo el JSON con la informacion de los datos de coleccion
    "RELATEDW", # aqui guardo el JSON con la informacion del trabajo relacionado con cada una de las obras
]

# %%
# creo el dataFrame vacio con las columnas necesarias
paintsFrame = pd.DataFrame(columns = soupCol)

# %%
# pruebo si todo cargo bien
paintsFrame.head()
# Out:
# Empty DataFrame
# Columns: [ID, NAME, ELEMENT_URL, DOWNLOAD_URL, HAS_ID, HAS_NAME, HAS_DESCRIPTION, HAS_DOWNLOAD, HAS_TAGS, HAS_DATA, HAS_RELATEDW, ERR_ID, ERR_NAME, ERR_DESCRIPTION, ERR_DOWNLOAD, ERR_TAGS, ERR_DATA, ERR_RELATEDW, DESCRIPTION, TAGS, DATA, RELATEDW]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ### Pagina Fuente (Root Page)
# desde la pagina fuente recupero todos los enlaces a las obras de Vangohg y despues con la lista de enlaces recupero la informacion necesaria
#
# #### Creando el indice de la coleccion
# creo el URL de busqueda en la pagina principal de la coleccion para extraer los URLs de los elementos creados por Van Gogh, para pruebas mantengo un numero limitado de URLs a recuperar.

# %%
# Se recorre la pagina principal y recuperan los enlaces de l 
# numero de paginas/obras/enlaces a iterar

paints = 1200
defaultPaints = 50

# maximo numero de pinturas conocidas
maxPaints = 1443

# busqueda base en la coleccion de Vangogh

paintsSearch = "https://vangoghmuseum.nl/en/search/collection?q=&artist=Vincent%20van%20Gogh&pagesize="
paintsRoot = "https://vangoghmuseum.nl"

# por defecto pruebo 50 elementos de la coleccion
paintsPage = paintsSearch + str(defaultPaints)

# si el numero de enlaces a buscar esta en el rango a propiado
if paints <= maxPaints and paints > 0:
    paintsPage = paintsSearch + str(paints)

# si el numero de enlaces es superior al maximo
elif paints > maxPaints:
    paintsPage = paintsSearch + str(maxPaints)

# si hay algo raro
else:
    paintsPage = paintsSearch + str(defaultPaints)

# reviso que cargue bien la pagina base
print("--- Search URL ---")
print(paintsPage)
# Out:
# --- Search URL ---
# https://vangoghmuseum.nl/en/search/collection?q=&artist=Vincent%20van%20Gogh&pagesize=1200

# %%
# lista de enlaces, IDs nombres a elementos de la coleccion
links = list()
ids = list()
names = list()

# objetos necesarios para scrapy en beatifulsoup: handler y resultados
soup = None
linkSoup = list()
nameSoup = list()
errIDs = list()

# diccionario caracterisico para la busqueda para el enlace del elemento de la galeria
linkAttr = {"class":"link-teaser triggers-slideshow-effect", "href":re.compile("^/en/collection/")}

# diccionario caracterisico para la busqueda del nombre del elemento de la galeria
nameAttr = {"class":"text-base text-dark"}

try:
    # GET del URL
    pageReq = requests.get(paintsPage)

    # si el GET me responde bien con codigo 200
    if pageReq.status_code == 200:

        # uso beautifulSoup
        soup = BeautifulSoup(pageReq.content, "html.parser")

        # esta es la seccion del HTML donde estan los enlaces con tag 'a'
        linkSoup = soup.body.findAll("a", attrs = linkAttr)
        
        # esta es la seccion del HTML donde estan los enlaces con tag 'h3'
        nameSoup = soup.body.findAll("h3", attrs = nameAttr)
        
        # si no hay errores agrego un mensaje vacio para no danhar el dataframe
        errIDs.append(None)

# si algo pasa aca esto esta muy mal
except Exception as e:
    print("In URL: " + paintsPage + "\nError: " + str(e))
    print("Status Code: " + str(linkReq.status_code))
    errIDs.append(e)

# %%
# saco los links e IDs a las paginas que quiero dentro de la coleccion
# estan los elementos de tipo link-teaser y la expresion regular del href
names = list()
errNames = list()
hasNames = list()

for name in nameSoup:

    try:

        # reconstruyo el enlace completo
        tempName = re.sub("\s+", " ", name.string)
        tempName = tempName[1:-1]
        names.append(tempName)
        
        # si no hay errores agrego un mensaje vacio para no danhar el dataframe
        errNames.append(None)
        hasNames.append(bool(True))

    except Exception as e:
        print("Error in: " + str(e))
        errNames.append(e)
        hasNames.append(bool(False))

# %%
# saco los links e IDs a las paginas que quiero dentro de la coleccion
# estan los elementos de tipo link-teaser y la expresion regular del href
ids = list()
links = list()

# lista de mensjaes de error y de booleanos de la operacion de sobre IDs
errIDs = list()
hasIDs = list()

for link in linkSoup:

    try:

        # reconstruyo el enlace completo
        tempLink = urllib.parse.urljoin(paintsRoot, link.get("href"))
        tempID = link.get("href").replace("/en/collection/", "")
        
        # nombre e ID para la columna del dataFrame
        ids.append(tempID)
        links.append(tempLink)
        
        # si no hay errores agrego un mensaje vacio para no danhar el dataframe
        errIDs.append(None)
        hasIDs.append(bool(True))

    except Exception as e:
        print("Error in: " + str(e))
        errIDs.append(e)
        hasIDs.append(bool(False))

# %%
# creo un frame para la busqueda que se desea hacer 
searchFrame = pd.DataFrame(columns = soupCol)

# se actualizan los datos de este dataframe con lo que se busco anteriormente
searchFrame["ID"] = ids
searchFrame["ELEMENT_URL"] = links 
searchFrame["NAME"] = names
searchFrame["ERR_ID"] = errIDs
searchFrame["HAS_ID"] = hasIDs
searchFrame["ERR_NAME"] = errNames
searchFrame["HAS_NAME"] = hasNames

# %%
# chequeo que lo que busque esta bien formado
searchFrame.info()
searchFrame.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 22 columns):
# ID                 1200 non-null object
# NAME               1200 non-null object
# ELEMENT_URL        1200 non-null object
# DOWNLOAD_URL       0 non-null object
# HAS_ID             1200 non-null bool
# HAS_NAME           1200 non-null bool
# HAS_DESCRIPTION    0 non-null object
# HAS_DOWNLOAD       0 non-null object
# HAS_TAGS           0 non-null object
# HAS_DATA           0 non-null object
# HAS_RELATEDW       0 non-null object
# ERR_ID             0 non-null object
# ERR_NAME           0 non-null object
# ERR_DESCRIPTION    0 non-null object
# ERR_DOWNLOAD       0 non-null object
# ERR_TAGS           0 non-null object
# ERR_DATA           0 non-null object
# ERR_RELATEDW       0 non-null object
# DESCRIPTION        0 non-null object
# TAGS               0 non-null object
# DATA               0 non-null object
# RELATEDW           0 non-null object
# dtypes: bool(2), object(20)
# memory usage: 190.0+ KB
#                 ID                          NAME  \
# count         1200                          1200
# unique        1200                           871
# top     d0441V1962  Head of a Woman, 1884 - 1885
# freq             1                            29
#
#                                               ELEMENT_URL DOWNLOAD_URL HAS_ID  \
# count                                                1200            0   1200
# unique                                               1200            0      1
# top     https://vangoghmuseum.nl/en/collection/d0035V1962          NaN   True
# freq                                                    1          NaN   1200
#
#        HAS_NAME HAS_DESCRIPTION HAS_DOWNLOAD HAS_TAGS HAS_DATA  ... ERR_NAME  \
# count      1200               0            0        0        0  ...        0
# unique        1               0            0        0        0  ...        0
# top        True             NaN          NaN      NaN      NaN  ...      NaN
# freq       1200             NaN          NaN      NaN      NaN  ...      NaN
#
#        ERR_DESCRIPTION ERR_DOWNLOAD ERR_TAGS ERR_DATA ERR_RELATEDW  \
# count                0            0        0        0            0
# unique               0            0        0        0            0
# top                NaN          NaN      NaN      NaN          NaN
# freq               NaN          NaN      NaN      NaN          NaN
#
#        DESCRIPTION TAGS DATA RELATEDW
# count            0    0    0        0
# unique           0    0    0        0
# top            NaN  NaN  NaN      NaN
# freq           NaN  NaN  NaN      NaN
#
# [4 rows x 22 columns]

# %%
# si existe el CSV de busquedas nteriorres se carga lo que existe
galleryFile = "VanGoghGalleryIndex.csv"
dataFolder = "data"

if os.path.exists(dataFolder):
    
    # si el CSV de index ya existe
    galleryBackup = os.path.join(os.getcwd(), dataFolder, galleryFile)
    
    if os.path.exists(galleryBackup):
         
        # lo leo y lo cargo en el DataFrame
        paintsFrame = pd.read_csv(galleryBackup, sep = ",", encoding = "utf-8", engine = "python")#, index_col = [0])

# %%
# agregos los detalles de la nueva busqueda sobre el dataframe de la busqueda anterior
paintsFrame = pd.concat([searchFrame, paintsFrame]).drop_duplicates(["ID", "NAME"], keep = "last").sort_index()

# %%
#chequeo la informacion recuperada de la busqueda
print("Extracted links in search: " + str(len(links)))
print("Repeated link elements: " + str(len(links) != len(set(links))))

print("Extracted IDs in search: " + str(len(ids)))
print("Repeated IDs elements: " + str(len(ids) != len(set(ids))))

print("Extracted names in search: " + str(len(names)))
print("Repeated names elements: " + str(len(names) != len(set(names))))

print("Shape: " + str(paintsFrame.shape))

#chquueo como va todo
paintsFrame.info()
paintsFrame.head()
# Out:
# Extracted links in search: 1200
# Repeated link elements: False
# Extracted IDs in search: 1200
# Repeated IDs elements: False
# Extracted names in search: 1200
# Repeated names elements: True
# Shape: (1200, 22)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1200 entries, 0 to 1199
# Data columns (total 22 columns):
# ID                 1200 non-null object
# NAME               1200 non-null object
# ELEMENT_URL        1200 non-null object
# DOWNLOAD_URL       1200 non-null object
# HAS_ID             1200 non-null bool
# HAS_NAME           1200 non-null bool
# HAS_DESCRIPTION    1200 non-null object
# HAS_DOWNLOAD       1200 non-null object
# HAS_TAGS           1200 non-null object
# HAS_DATA           1200 non-null object
# HAS_RELATEDW       1200 non-null object
# ERR_ID             0 non-null object
# ERR_NAME           0 non-null object
# ERR_DESCRIPTION    0 non-null object
# ERR_DOWNLOAD       168 non-null object
# ERR_TAGS           161 non-null object
# ERR_DATA           161 non-null object
# ERR_RELATEDW       0 non-null object
# DESCRIPTION        1200 non-null object
# TAGS               1200 non-null object
# DATA               1200 non-null object
# RELATEDW           400 non-null object
# dtypes: bool(2), object(20)
# memory usage: 199.2+ KB
#            ID                                               NAME  \
# 0  s0005V1962                            The Potato Eaters, 1885
# 1  s0019V1962  Garden with Courting Couples: Square Saint-Pie...
# 2  s0027V1962                          The Langlois Bridge, 1888
# 3  s0029V1962                                    The Sower, 1888
# 4  s0031V1962                                   Sunflowers, 1889
#
#                                          ELEMENT_URL  \
# 0  https://vangoghmuseum.nl/en/collection/s0005V1962
# 1  https://vangoghmuseum.nl/en/collection/s0019V1962
# 2  https://vangoghmuseum.nl/en/collection/s0027V1962
# 3  https://vangoghmuseum.nl/en/collection/s0029V1962
# 4  https://vangoghmuseum.nl/en/collection/s0031V1962
#
#                                         DOWNLOAD_URL  HAS_ID  HAS_NAME  \
# 0  https://vangoghmuseum.nl/download/8bc21467-2e7...    True      True
# 1  https://vangoghmuseum.nl/download/12bd07b2-3c2...    True      True
# 2  https://vangoghmuseum.nl/download/c82c2fcd-90e...    True      True
# 3  https://vangoghmuseum.nl/download/61fbedad-1d6...    True      True
# 4  https://vangoghmuseum.nl/download/597e7189-79d...    True      True
#
#   HAS_DESCRIPTION HAS_DOWNLOAD HAS_TAGS HAS_DATA  ... ERR_NAME  \
# 0            True         True     True     True  ...      NaN
# 1            True         True     True     True  ...      NaN
# 2            True         True     True     True  ...      NaN
# 3            True         True     True     True  ...      NaN
# 4            True         True     True     True  ...      NaN
#
#   ERR_DESCRIPTION ERR_DOWNLOAD ERR_TAGS ERR_DATA ERR_RELATEDW  \
# 0             NaN          NaN      NaN      NaN          NaN
# 1             NaN          NaN      NaN      NaN          NaN
# 2             NaN          NaN      NaN      NaN          NaN
# 3             NaN          NaN      NaN      NaN          NaN
# 4             NaN          NaN      NaN      NaN          NaN
#
#                                          DESCRIPTION  \
# 0  {\n    "tittle": "The Potato Eaters",\n    "au...
# 1  {\n    "tittle": "Garden with Courting Couples...
# 2  {\n    "tittle": "The Langlois Bridge",\n    "...
# 3  {\n    "tittle": "The Sower",\n    "authorship...
# 4  {\n    "tittle": "Sunflowers",\n    "authorshi...
#
#                                                 TAGS  \
# 0  {\n    "tags": {\n        "references": [\n   ...
# 1  {\n    "tags": {\n        "references": [\n   ...
# 2  {\n    "tags": {\n        "references": [\n   ...
# 3  {\n    "tags": {\n        "references": [\n   ...
# 4  {\n    "tags": {\n        "references": [\n   ...
#
#                                                 DATA  \
# 0  {\n    "F_number": "F0082",\n    "JH_number": ...
# 1  {\n    "F_number": "F0314",\n    "JH_number": ...
# 2  {\n    "F_number": "F0400",\n    "JH_number": ...
# 3  {\n    "F_number": "F0451",\n    "JH_number": ...
# 4  {\n    "F_number": "F0458",\n    "JH_number": ...
#
#                                             RELATEDW
# 0  {\n    "relations": {\n        "references": [...
# 1  {\n    "relations": {\n        "references": [...
# 2  {\n    "relations": {\n        "references": [...
# 3  {\n    "relations": {\n        "references": [...
# 4  {\n    "relations": {\n        "references": [...
#
# [5 rows x 22 columns]

# %%
# guardando los links en TXT y CSV para backup del proceso y control de calidad
galleryIndex = "VanGoghGalleryIndex.txt"
galleryFile = "VanGoghGalleryIndex.csv"
dataFolder = "data"

# guardando archivo original de texto
# si no existe el directorio
if not os.path.exists(dataFolder):
    
    os.makedirs(dataFolder)

# si existe el directorio
else: 
    
    # sobreescribo el archivo siempre
    # guardo los enlaces en un TXT por si acaso
    with open(os.path.join(os.getcwd(), dataFolder, galleryIndex), "w", encoding = "utf-8", errors = "ignore") as file:
        for link in links:
            file.write("%s\n" % link)
    
    # guardo el DataFrame segun las ultimas actualizaciones
    paintsFrame.to_csv(os.path.join(os.getcwd(), dataFolder, galleryFile), sep = ",", index = False, encoding = "utf-8", mode = "w")

# %% [markdown]
# ### Directorio y Carpetas para persistencia
# configuro donde se va a guardar la informacion inicial dentro de OneDrive (gitHub no me deja), creo las carpetas y desacoplo el computador donde corre el script. Despues ejecuto los siguientes pasos:
#
# - Creo el folder fuente "01 - Raw".
# - Dentro del folder fuente creo los folderes "01 - Paints" y "02 - Letters".
# - Creo las carpetas necesarias dentro de "01 - Paints" con el ID del dataframe.

# %%
# defino los directorios locales donde se va a persistir la informacion
# no olvidarse del cambiar "\" a "\\" en los filepath de windows por que si no no sirve nada
# dir de santiago
SFAM_ROOT = "C:\\Users\\Felipe\\OneDrive - Universidad de Los Andes\\03 - PhD\\04 - Clases\\05 - IA en Arte y Disenho\\03 - Proyecto\\01 - Data\\01 - Raw"
# dir de daniela
DCP_ROOT = ""
# variable intermedia para independizar, se comenta uno u otro segun donde se corra
WORK_ROOT = SFAM_ROOT
# WORK_ROOT = DCP_ROOT

# nombres de carpetas utiles donde se guarda la informacion
rawFolder = "01 - Raw"
paintsFolder = "01 - Paints"
lettersFolder = "02 - Letters"

#La ruta se obtiene con el dirpath y el filename y el dirpath.split(os.path.sep)[-1] agrega la clase
DATA_ROOT = os.path.dirname(WORK_ROOT)
print(DATA_ROOT)
# Out:
# C:\Users\Felipe\OneDrive - Universidad de Los Andes\03 - PhD\04 - Clases\05 - IA en Arte y Disenho\03 - Proyecto\01 - Data

# %%
# preparar el directorio de trabajo
# si la ruta de trabajo local esta definida
workPath = ""

# si no eexiste el ROOT apropiado, esto lo debe arreglar el usuario
if not os.path.exists(WORK_ROOT):
    
    print("Make sure the WORK_ROOT is correct in your local HD!!!...")

# si si existe el root apropiado, configuro los folderes para guardar la informacion
elif os.path.exists(WORK_ROOT):

    # concateno los folders para la nueva carpeta de trabajo
    workPath = os.path.join(DATA_ROOT, rawFolder, paintsFolder)

    # si todo va bien y necesito crear nuevo folder de trabajo
    if not os.path.exists(workPath):
        
        # creo folderes nuevos
        os.makedirs(workPath)
        print("creating proper folder configuration!!!...")
    
    # si los folderes ya existen
    if os.path.exists(workPath):
        
        print("Working folders and config are cool... carry on!...")
# Out:
# Working folders and config are cool... carry on!...

# %% [markdown]
# ### Crear subfolders de las pinturas
# Con la columna de "ELEMENT_URL" e "ID" del data frame se hacen los siguientes pasos:
#
# - Revisar los enlaces de "ELEMENT_URL" para ver si se puede recuperar la informacion de la galeria.
# - crear folders por cada elemento de la galeria con nombre basado en el "ID".
# - si ya estan las cosas no se repite el trabajo.

# %%
# recorro el arreglo de enlaces habilitados para extraer la informacion
# creo las carpetas necesarias, si ya existen no las sobreescribo.
links = list(paintsFrame["ELEMENT_URL"])
# en este caso los IDs son los nombres de los folders en local
folders = list(paintsFrame["ID"])

# variables de control de calidad del proceso, en este caso en las columnas, "ID", "HAS_ID", "ERR_ID"
errList = list()
hasList = list()

#inicio del ciclo para los enlaces, zip funciona para iterar 2 arreglos al tiempo
for folder in folders:
            
    # chequeo si el enlace sirve para sacar la informacion
    try:
                                
        # creo path para cada elemento en la coleccion
        tempPaintFolder = os.path.join(workPath, folder)

        # creo la carpeta del nuevo elemento de la coleccion si no existe
        if not os.path.exists(tempPaintFolder):

            os.makedirs(tempPaintFolder)
            # si no hay errores agrego un mensaje vacio para no danhar el dataframe
            errList.append(None)
            hasList.append(bool(True))
            
        # si existe la carpeta no hago nada
        elif os.path.exists(tempPaintFolder):
            # print("Folder " + str(folder) + " already exists...")
            # si no hay errores agrego un mensaje vacio para no danhar el dataframe
            errList.append(None)
            hasList.append(bool(True))

    except Exception as e:
        print("In URL: " + link + "\nError: " + str(e))
        print("Status Code: " + str(linkReq.status_code))
        errList.append(e)
        hasList.append(bool(False))

# %%
# actualizo el dataFrame para ver si hay errores
paintsFrame["HAS_ID"] = hasList
paintsFrame["ERR_ID"] = errList

# %%
# chequeo como va el dataframe de procesamiento
paintsFrame.info()
paintsFrame.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1200 entries, 0 to 1199
# Data columns (total 22 columns):
# ID                 1200 non-null object
# NAME               1200 non-null object
# ELEMENT_URL        1200 non-null object
# DOWNLOAD_URL       1200 non-null object
# HAS_ID             1200 non-null bool
# HAS_NAME           1200 non-null bool
# HAS_DESCRIPTION    1200 non-null object
# HAS_DOWNLOAD       1200 non-null object
# HAS_TAGS           1200 non-null object
# HAS_DATA           1200 non-null object
# HAS_RELATEDW       1200 non-null object
# ERR_ID             0 non-null object
# ERR_NAME           0 non-null object
# ERR_DESCRIPTION    0 non-null object
# ERR_DOWNLOAD       168 non-null object
# ERR_TAGS           161 non-null object
# ERR_DATA           161 non-null object
# ERR_RELATEDW       0 non-null object
# DESCRIPTION        1200 non-null object
# TAGS               1200 non-null object
# DATA               1200 non-null object
# RELATEDW           400 non-null object
# dtypes: bool(2), object(20)
# memory usage: 199.2+ KB
#                 ID                          NAME  \
# count         1200                          1200
# unique        1200                           871
# top     d0441V1962  Head of a Woman, 1884 - 1885
# freq             1                            29
#
#                                               ELEMENT_URL  \
# count                                                1200
# unique                                               1200
# top     https://vangoghmuseum.nl/en/collection/d0035V1962
# freq                                                    1
#
#                                              DOWNLOAD_URL HAS_ID HAS_NAME  \
# count                                                1200   1200     1200
# unique                                               1200      1        1
# top     https://vangoghmuseum.nl/en/collection/b0628V1962   True     True
# freq                                                    1   1200     1200
#
#        HAS_DESCRIPTION HAS_DOWNLOAD HAS_TAGS HAS_DATA  ... ERR_NAME  \
# count             1200         1200     1200     1200  ...        0
# unique               1            2        1        2  ...        0
# top               True         True     True     True  ...      NaN
# freq              1200         1032     1200     1039  ...      NaN
#
#        ERR_DESCRIPTION                                       ERR_DOWNLOAD  \
# count                0                                                168
# unique               0                                                168
# top                NaN  Download file unavailable in URL:https://vango...
# freq               NaN                                                  1
#
#                                                  ERR_TAGS  \
# count                                                 161
# unique                                                161
# top     Tags unavailable in URL:https://vangoghmuseum....
# freq                                                    1
#
#                                                  ERR_DATA ERR_RELATEDW  \
# count                                                 161            0
# unique                                                161            0
# top     Data Object unavailable in URL:https://vangogh...          NaN
# freq                                                    1          NaN
#
#                                               DESCRIPTION  \
# count                                                1200
# unique                                               1136
# top     {\n    "tittle": "Horse",\n    "authorship": {...
# freq                                                    5
#
#                                                      TAGS  \
# count                                                1200
# unique                                                332
# top     {\n    "tags": {\n        "references": []\n  ...
# freq                                                  161
#
#                                                      DATA  \
# count                                                1200
# unique                                               1040
# top     {\n    "F_number": "",\n    "JH_number": "",\n...
# freq                                                  161
#
#                                                  RELATEDW
# count                                                 400
# unique                                                 74
# top     {\n    "relations": {\n        "references": [...
# freq                                                  312
#
# [4 rows x 22 columns]

# %%
# guardando los links en TXT y CSV para backup del proceso y control de calidad
galleryFile = "VanGoghGalleryIndex.csv"
dataFolder = "data"

# actualizando archivo original CSV
# si no existe el directorio
if not os.path.exists(dataFolder):
    
    os.makedirs(dataFolder)

# si existe el directorio
else: 
    
    # guardo el DataFrame segun las ultimas actualizaciones
    paintsFrame.to_csv(os.path.join(os.getcwd(), dataFolder, galleryFile), sep = ",", index = False, encoding = "utf-8", mode = "w")

# %% [markdown]
# ### Recuperar enlace de imagen de la galeria
# Con la columna de "ELEMENT_URL", "ID" y "DOWNLOAD_URL" del dataFrame se hacen los siguientes pasos:
#
# - Revisar si existe un enlace valido en "DOWNLOAD_URL", si no existe se sigue adelante.
# - Si no existe el enlace valido, utilizo
# Revisar los enlaces de "ELEMENT_URL" para ver si se puede recuperar la informacion de la galeria.
# - crear folders por cada elemento de la galeria con nombre basado en el "ID".
# - si ya estan las cosas no se repite el trabajo.

# %%
# recorro el arreglo de enlaces habilitados para extraer la informacion
# creo las carpetas necesarias, si ya existen no las sobreescribo.
links = list(paintsFrame["ELEMENT_URL"])
# en este caso los IDs son los nombres de los folders en local
folders = list(paintsFrame["ID"])
# lista de enlaces de descarga de imagenes en la galeria
downloads = list(paintsFrame["DOWNLOAD_URL"])
# lista de errores en el CSV
errors = list(paintsFrame["ERR_DOWNLOAD"])
# lista de existencia en el CSV
proofs = list(paintsFrame["HAS_DOWNLOAD"])

# lista de posibles nuevos enlaces de imagenes en la galeria
newData = list()

# variables de control de calidad del proceso, en este caso en las columnas, "ID", "HAS_ID", "ERR_ID"
errList = list()
hasList = list()

# atributos de la busqueda en beatifulsoup para la imagen tradicional
downAttrs = {"class":"button dark-hover", "href":re.compile("^/download/")}

# atributos de la busqueda en beatifulsoup para el resumen de carta
# "col set-header-image is-page a4portrait"
# "col set-header-image is-page a4landscape"
letterAttrs = {"class":re.compile("a4portrait|a4landscape")}

counter = 0

print("Number of elements in Gallery: " + str(len(links)))
print("Number of local folders for the Gallery: " + str(len(folders)))
print("Number of expected links for download: " + str(len(downloads)))

#inicio del ciclo para los enlaces, zip funciona para iterar 2 arreglos al tiempo
for link, folder, down, err, has in zip(links, folders, downloads, errors, proofs):
    
    # chequeo si el enlace sirve para sacar la informacion
    try:
        
        # inicializo uuna variable temporal
        tempLink = ""
        # print(counter)
        
        # si ya existe el URL de descarga lo repito en la columna
        if validators.url(str(down)) and validators.url(link):
            
            # si no hay errores agrego un mensaje vacio para no danhar el dataframe
            errList.append(err)
            hasList.append(has)
            newData.append(down)
            counter += 1
            
        # chequeo si existe un enlace de descarga de imagen y uno del elemento de la galeria
        elif not validators.url(str(down)) and validators.url(link):
            
            # GET del URL
            linkReq = requests.get(link)
        
            # si el GET me responde bien con codigo 200
            if linkReq.status_code == 200:
         
                # creo path para cada elemento en la coleccion
                tempPaintFolder = os.path.join(workPath, folder)

                # si existe la carpeta, descargo la imagen de la obra dentro de la coleccion de una vez
                if os.path.exists(tempPaintFolder):

                    # parser del cuerpo del elemento de la coleccion
                    linkSoup = BeautifulSoup(linkReq.content, "html.parser")
                    
                    # si es una obra dentro de la galeria
                    if linkSoup.find("a", attrs = downAttrs) != None:
                    
                        # busco todos los elementos de tipo class="button dark-hover"
                        downloadSoup = linkSoup.find("a", attrs = downAttrs)

                        # creo el enlace para descargar la imagen
                        tempLink = urllib.parse.urljoin(paintsRoot, downloadSoup.get("href"))

                        # pido el enlace de la imagen
                        downReq = requests.get(tempLink)

                        # creo el nombre y la direccion del archivo que quiero guardar en la carpeta
                        fileName = urlparse(tempLink)
                        fileName = fileName.path.split("/")[len(fileName.path.split("/"))-1]
                        filePath = os.path.join(tempPaintFolder, fileName)
                        
                        # si el archivo no existe lo guardo
                        if not os.path.exists(filePath):

                            # creo un archivo jpg para guardar la imagen del enlace
                            with open(filePath, "wb") as file:
                                file.write(downReq.content)
                                file.close()
                        
                        # si no hay errores agrego un mensaje vacio para no danhar el dataframe
                        errList.append(None)
                        hasList.append(bool(True))
                        
                        # no importa lo que pase guardo el link de descarga 
                        newData.append(tempLink)
                        counter += 1
                    
                    # si es una carta y no tiene su foto
                    elif linkSoup.find("div", attrs = letterAttrs) != None:
                        
                        # print("Download File Unavailable in: " + str(link))
                        err = "Download file unavailable in URL: " + str(link) + "\n Request time: " + str(datetime.datetime.now())
                        
                        # si no hay errores agrego un mensaje vacio para no danhar el dataframe
                        errList.append(err)
                        hasList.append(bool(False))
                        
                        # guardo el link del elemento padre de la descarga 
                        newData.append(link)                                                 
                        counter += 1
                    
                    # no es nada de lo que espero
                    elif linkSoup.find("a", attrs = downAttrs) == None or linkSoup.find("div", attrs = letterAttrs) == None:
                        
                        # print("this is weird!!!!!")
                        err = "Download file NOT FOUND in URL: " + str(link) + "\n Request time: " + str(datetime.datetime.now())

                        # si no hay errores agrego un mensaje vacio para no danhar el dataframe
                        errList.append(err)
                        hasList.append(bool(False))
                        
                        # guardo el link del elemento padre de la descarga 
                        newData.append(link)                                                 
                        counter += 1                        

    except Exception as e:
        print("In URL: " + link + "\nError: " + str(e))
        print("Status Code: " + str(linkReq.status_code))
        newData.append("In URL: " + link + "\nError: " + str(e))
        errList.append(e)
        hasList.append(bool(False))
# Out:
# Number of elements in Gallery: 1200
# Number of local folders for the Gallery: 1200
# Number of expected links for download: 1200

# %%
print("Number of Download operations: " + str(counter))
print("Number of downloads: " + str(len(newData)))
print("Number of completed operations: " + str(len(hasList)))
print("Number of error reports: " + str(len(errList)))
# Out:
# Number of Download operations: 1200
# Number of downloads: 1200
# Number of completed operations: 1200
# Number of error reports: 1200

# %%
# actualizo el dataFrame para ver si hay errores
paintsFrame["DOWNLOAD_URL"] = newData
paintsFrame["HAS_DOWNLOAD"] = hasList
paintsFrame["ERR_DOWNLOAD"] = errList

# %%
# chequeo como va el dataframe de procesamiento
paintsFrame.info()
paintsFrame.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1200 entries, 0 to 1199
# Data columns (total 22 columns):
# ID                 1200 non-null object
# NAME               1200 non-null object
# ELEMENT_URL        1200 non-null object
# DOWNLOAD_URL       1200 non-null object
# HAS_ID             1200 non-null bool
# HAS_NAME           1200 non-null bool
# HAS_DESCRIPTION    1200 non-null object
# HAS_DOWNLOAD       1200 non-null bool
# HAS_TAGS           1200 non-null object
# HAS_DATA           1200 non-null object
# HAS_RELATEDW       1200 non-null object
# ERR_ID             0 non-null object
# ERR_NAME           0 non-null object
# ERR_DESCRIPTION    0 non-null object
# ERR_DOWNLOAD       168 non-null object
# ERR_TAGS           161 non-null object
# ERR_DATA           161 non-null object
# ERR_RELATEDW       0 non-null object
# DESCRIPTION        1200 non-null object
# TAGS               1200 non-null object
# DATA               1200 non-null object
# RELATEDW           400 non-null object
# dtypes: bool(3), object(19)
# memory usage: 191.0+ KB
#                 ID                          NAME  \
# count         1200                          1200
# unique        1200                           871
# top     d0441V1962  Head of a Woman, 1884 - 1885
# freq             1                            29
#
#                                               ELEMENT_URL  \
# count                                                1200
# unique                                               1200
# top     https://vangoghmuseum.nl/en/collection/d0035V1962
# freq                                                    1
#
#                                              DOWNLOAD_URL HAS_ID HAS_NAME  \
# count                                                1200   1200     1200
# unique                                               1200      1        1
# top     https://vangoghmuseum.nl/en/collection/b0628V1962   True     True
# freq                                                    1   1200     1200
#
#        HAS_DESCRIPTION HAS_DOWNLOAD HAS_TAGS HAS_DATA  ... ERR_NAME  \
# count             1200         1200     1200     1200  ...        0
# unique               1            2        1        2  ...        0
# top               True         True     True     True  ...      NaN
# freq              1200         1032     1200     1039  ...      NaN
#
#        ERR_DESCRIPTION                                       ERR_DOWNLOAD  \
# count                0                                                168
# unique               0                                                168
# top                NaN  Download file unavailable in URL:https://vango...
# freq               NaN                                                  1
#
#                                                  ERR_TAGS  \
# count                                                 161
# unique                                                161
# top     Tags unavailable in URL:https://vangoghmuseum....
# freq                                                    1
#
#                                                  ERR_DATA ERR_RELATEDW  \
# count                                                 161            0
# unique                                                161            0
# top     Data Object unavailable in URL:https://vangogh...          NaN
# freq                                                    1          NaN
#
#                                               DESCRIPTION  \
# count                                                1200
# unique                                               1136
# top     {\n    "tittle": "Horse",\n    "authorship": {...
# freq                                                    5
#
#                                                      TAGS  \
# count                                                1200
# unique                                                332
# top     {\n    "tags": {\n        "references": []\n  ...
# freq                                                  161
#
#                                                      DATA  \
# count                                                1200
# unique                                               1040
# top     {\n    "F_number": "",\n    "JH_number": "",\n...
# freq                                                  161
#
#                                                  RELATEDW
# count                                                 400
# unique                                                 74
# top     {\n    "relations": {\n        "references": [...
# freq                                                  312
#
# [4 rows x 22 columns]

# %%
# guardando los links en TXT y CSV para backup del proceso y control de calidad
galleryFile = "VanGoghGalleryIndex.csv"
dataFolder = "data"

# actualizando archivo original CSV
# si no existe el directorio
if not os.path.exists(dataFolder):
    
    os.makedirs(dataFolder)

# si existe el directorio
else: 
    
    # guardo el DataFrame segun las ultimas actualizaciones
    paintsFrame.to_csv(os.path.join(os.getcwd(), dataFolder, galleryFile), sep = ",", index = False, encoding = "utf-8", mode = "w")

# %% [markdown]
# ### Recuperar la descripcion del elemento de la galeria
#
# Con la columna de "ELEMENT_URL", "ID", "HAS_DESCRIPTION" y "ERR_DESCRIPTION" del dataFrame se hacen los siguientes pasos:
#
# - Revisar el enlace en "ELEMENT_URL" si el enlace esta activo se sigue adelante.
# - se recupera la seccion donde esta la descripcion del elemento.
# - se actualiza el dataframe para mantener la trasabilidad del proceso.
# - si la descripcion ya esta, no se repite el trabajo.
#
# se supone que los subfolders de los elementos ya existen.

# %%
# recorro el arreglo de enlaces habilitados para extraer la informacion
# creo las carpetas necesarias, si ya existen no las sobreescribo.
links = list(paintsFrame["ELEMENT_URL"])
# en este caso los IDs son los nombres de los folders en local
folders = list(paintsFrame["ID"])
# deberia haber un JSON en esta columna
descriptions = list(paintsFrame["DESCRIPTION"])
# lista de errores en el CSV
errors = list(paintsFrame["ERR_DESCRIPTION"])
# lista de existencia en el CSV
proofs = list(paintsFrame["HAS_DESCRIPTION"])

# variables de control de calidad del proceso, en este caso en las columnas, "HAS_DESCRIPTION", "ERR_DESCRIPTION"
errList = list()
hasList = list()

# lista donde se guarda la nueva informacion que se recupera de la descripcion y contenido de la obra.
newData = list()

# atributos de la busqueda en beatifulsoup para una pintura
soupTag = "article"
soupAttrs = {"class":"col"}

# atributos de la busqueda en beatifulsoup para una carta
letterTag = "div"
letterAttrs = {"class":"col set-header-text"}

# formato del diccionario para el JSON de persistencia de la descripcion del elemento
infoDictSchema = {
    "tittle": str(), # nombre o titulo de la obra.
    "authorship": { # diccionario para la autoria de la obra, nombre del autor, lugar y fecha aproximada.
        "name": str(),
        "place": str(),
        "date": str(),
    }, 
    "description": { # diccionario para la descripcion basica de la obra, medio y dimensiones.
        "medium": str(),
        "dimensions": str(),
    },
    "credits": { # diccionario para describir los creditos asociados con la obra.
        "holder": str(),
        "place": str(),
    }, 
    "content": { # diccionario con la descripcion detallada del contenido de la obra y de ser necesario los links asociados
        "text": str(),
        "references": list()
    } 
}

# contador de la operacion
counter = 0

print("Number of elements in Gallery: " + str(len(links)))
print("Number of local folders for the Gallery: " + str(len(folders)))
print("Number of expected descriptions: " + str(len(descriptions)))

#inicio del ciclo para los enlaces, zip funciona para iterar 2 arreglos al tiempo
for link, folder, des, err, has in zip(links, folders, descriptions, errors, proofs):

    # chequeo si el enlace sirve para sacar la informacion
    try:
        # inicializo uuna variable temporal
        tempInfoDict = copy.deepcopy(infoDictSchema)

        # GET del URL
        linkReq = requests.get(link)

        # si el GET me responde bien con codigo 200
        if linkReq.status_code == 200:
            
            # creo path para cada elemento en la coleccion
            tempPaintFolder = os.path.join(workPath, folder)
            
            # creo el nombre del archivo JSON donde guardo la descripcion
            fileName = "des_" + folder + ".json"
            filePath = os.path.join(tempPaintFolder, fileName)

            # si lo que quiero guardar ya existe
            if os.path.exists(tempPaintFolder) and os.path.exists(filePath):

                # si no hay errores agrego un mensaje vacio para no danhar el dataframe
                hasList.append(has)           
                errList.append(err)
                
                # agrego el JSON en una columna del dataframe
                newData.append(des)
                counter += 1
                # print(counter)
            
            # si existe la carpeta y no existe el JSON, proceso la informacion de la descripcion
            elif os.path.exists(tempPaintFolder) and not os.path.exists(filePath):
                
                # parse del cuerpo del elemento de la coleccion
                linkSoup = BeautifulSoup(linkReq.content, "html.parser")
                
####################################################################################################################
####################################################################################################################
################################ PROCESANDO UNA OBRA DENTRO DE LA GALERIA ##########################################
####################################################################################################################
####################################################################################################################
                
                # si lo que estoy describiendo es una obra
                if linkSoup.find(soupTag, attrs = soupAttrs) != None:

                    # busco todos los elementos de tipo class="article"
                    downloadSoup = linkSoup.find(soupTag, attrs = soupAttrs)

                    # recuperando la informacion del titulo
                    tempInfoDict["tittle"] = downloadSoup.find("a", attrs = {"class":"text-underline-none", "name":"info"}).text
                    # print("---------------- Tittle -----------------\n" + tempInfoDict["tittle"])

                    # recuperando la informacion de la autoria de la obra, nombre del autor, lugar y fecha aproximada.
                    tempData = downloadSoup.find("p", attrs = {"class":"text-bold"}).text

                    # limpiando el texto de caracteres innecesarios
                    tempData = re.sub(" \s+", "", tempData)
                    tempData = re.sub("\n", "", tempData)
                    # print("---------------- Recovered Authorship Data-----------------\n" + str(tempData))
                    tempData = tempData.split(",")

                    if len(tempData) == 2:

                        # nombre del autor, lugar de autoria y fecha aproximada
                        tempInfoDict["authorship"]["name"] = tempData[0]
                        tempInfoDict["authorship"]["date"] = tempData[1]
                        # print("---------------- Authorship -----------------\n" + str(tempInfoDict["authorship"]))

                    elif len(tempData) == 3:

                        # nombre del autor, lugar de autoria y fecha aproximada
                        tempInfoDict["authorship"]["name"] = tempData[0]
                        tempInfoDict["authorship"]["place"] = tempData[1]
                        tempInfoDict["authorship"]["date"] = tempData[2]
                        # print("---------------- Authorship -----------------\n" + str(tempInfoDict["authorship"]))

                    # palabra clave en el esquema de la obra
                    keyWord = "Credits"

                    # recuperando la descripcion de la en un diccionario que contiene medio y dimensiones.
                    tempData = downloadSoup.find("p", attrs = {"class":"text-bold"}).findNext("p").text
                    # print("---------------- Recovered description Data-----------------\n" + str(tempData))

                    tempData = re.sub(" \s+", "", tempData)
                    tempData = re.sub("\n", "", tempData)
                    tempData = tempData.split(keyWord)
                    # print("---------------- Recovered description Data-----------------\n" + str(tempData))

                    # si encuentro el parrafo con los creditos con la estructura apropiada, dividido por ":"
                    if len(tempData) > 1:

                        # print("---------------- description after if -----------------\n" + str(tempData))
                        # tomo el primer elemento
                        tempData = tempData[0]
                        tempData = tempData.split(",")  
                        # print("---------------- description before compare -----------------\n" + str(tempData))

                        if len(tempData) == 1:

                            # print("---------------- description after split -----------------\n" + str(tempData))
                            # guardo en el diccionario el medio y las dimensiones
                            tempInfoDict["description"]["dimensions"] = tempData[0]
                            # print("---------------- description -----------------\n" + str(tempInfoDict["description"]))

                        elif len(tempData) == 2:

                            # print("---------------- description after split -----------------\n" + str(tempData))
                            # guardo en el diccionario el medio y las dimensiones
                            tempInfoDict["description"]["medium"] = tempData[0]
                            tempInfoDict["description"]["dimensions"] = tempData[1]
                            # print("---------------- description -----------------\n" + str(tempInfoDict["description"]))

                        elif len(tempData) > 2:

                            # print("---------------- description after split -----------------\n" + str(tempData))
                            # guardo en el diccionario el medio y las dimensiones
                            tempInfoDict["description"]["dimensions"] = tempData.pop()
                            tempInfoDict["description"]["medium"] = tempData
                            # print("---------------- description -----------------\n" + str(tempInfoDict["description"]))


                    # recuperando la descripcion de los creditos asociados con la obra.
                    tempData = downloadSoup.find("p", attrs = {"class":"text-bold"}).findNext("p").text
                    # limpio y preparo lo que encontre
                    tempData = re.sub(" \s+", "", tempData)
                    tempData = re.sub("\n", "", tempData)
                    tempData = tempData.split(":")                        

                    # si encuentro el parrafo con los creditos con la estructura apropiada, dividido por ":"
                    if len(tempData) == 2:

                        # tomo el ultimo elemento
                        tempData = tempData[len(tempData)-1]
                        # print("---------------- Recovered credits Data-----------------\n" + str(tempData))
                        tempData = tempData.split(",")      

                        # guardo en el diccionario el poseedor y locacion de los creditos
                        tempInfoDict["credits"]["holder"] = tempData[0]
                        tempInfoDict["credits"]["place"] = tempData[1]
                        # print("---------------- credits -----------------\n" + str(tempInfoDict["credits"]))

                    # si existe contenido dentro de la descripcion del elemento, no necesariamente existe!!!
                    if downloadSoup.find("hr", attrs = {"class":"reset-left"}) != None:               

                        # recuperando el contenido de la obra, OJO aqui puede haber enlaces a otros lados!!!!
                        tempData = downloadSoup.find("hr", attrs = {"class":"reset-left"}).findNext("p")
                        # print("---------------- Recovered content Data-----------------\n" + str(tempData))

                        # limpio el texto y guardo en el diccionario el texto del contenido
                        # si no hay espacios entre signos de puntionacion los pongo
                        tempData = re.sub(r"(?<=[.,;:])(?=[^\s])", r" ", tempData.text)
                        tempInfoDict["content"]["text"] = tempData

                        # lo vuelvo a recuperar porque lo altere anteriormente
                        tempData = downloadSoup.find("hr", attrs = {"class":"reset-left"}).findNext("p")

                        # guardo en el diccionario la lista de enlaces vacia
                        tempInfoDict["content"]["references"] = list()

                        # lista de posibles enlaces externos
                        linkList = list()

                        # creo una lista para guardar los links dentro del contenido si es que existen.
                        if len(tempData.findAll("a")) > 0:

                            # print("there are " + str(counter) + " links inside the description!!!!")
                            # counter += 1

                            for ref in tempData.findAll("a"):

                                newLink = {"text":ref.text, "link":ref.get("href")}
                                linkList.append(copy.deepcopy(newLink))

                        # guardo en el diccionario la lista de enlaces relevantes del texto.
                        tempInfoDict["content"]["references"] = copy.deepcopy(linkList)
                        # print("---------------- content -----------------\n" + str(tempInfoDict["description"]))

                    # esto siempre tiene que pasar!!!!
                    # transformo el dict a JSON.
                    jsonInfo = json.dumps(copy.deepcopy(tempInfoDict), ensure_ascii = False, indent = 4)

                    # guardo en un archivo el JSON de la descripcion.
                    with open(filePath, "w+", encoding = "utf-8") as file:
                        file.write(jsonInfo)
                        file.close()

                    # si no hay errores agrego un mensaje vacio para no danhar el dataframe
                    errList.append(None)
                    hasList.append(bool(True))
                    
                    # guardo un JSON creado en el CSV y en la carpeta
                    newData.append(jsonInfo)
                    counter += 1
                    # print(counter)
                    
####################################################################################################################
####################################################################################################################
############################### PROCESANDO UNA CARTA DENTRO DE LA GALERIA ##########################################
####################################################################################################################
####################################################################################################################

                # si lo que estoy describiendo es una carta
                elif  linkSoup.find(letterTag, attrs = letterAttrs) != None:
                                        
                    # recuperando la informacion del titulo
                    letterSoup = linkSoup.find(letterTag, attrs = letterAttrs)
                    
                    # recuperando el titulo de la carta/elemento
                    tempInfoDict["tittle"] = letterSoup.find("h1", attrs = {"class":"hr-accent"}).text
                    
                    # recuperando la informacion de la autoria de la obra, nombre del autor, lugar y fecha aproximada.
                    tempData = letterSoup.find("p", attrs = {"class":"text-bold"}).text

                    # limpiando el texto de caracteres innecesarios
                    tempData = re.sub(" \s+", "", tempData)
                    tempData = re.sub("\n", "", tempData)
                    # print("---------------- Recovered Authorship Data-----------------\n" + str(tempData))
                    tempData = tempData.split(",")
                    
                    if len(tempData) == 2:

                        # nombre del autor, lugar de autoria y fecha aproximada
                        tempInfoDict["authorship"]["name"] = tempData[0]
                        tempInfoDict["authorship"]["date"] = tempData[1]
                        # print("---------------- Authorship -----------------\n" + str(tempInfoDict["authorship"]))

                    elif len(tempData) == 3:

                        # nombre del autor, lugar de autoria y fecha aproximada
                        tempInfoDict["authorship"]["name"] = tempData[0]
                        tempInfoDict["authorship"]["place"] = tempData[1]
                        tempInfoDict["authorship"]["date"] = tempData[2]
                        # print("---------------- Authorship -----------------\n" + str(tempInfoDict["authorship"]))
                    
                    # palabra clave en el esquema de la obra
                    keyWord = "Credits"

                    # recuperando la descripcion de la en un diccionario que contiene medio y dimensiones.
                    tempData = letterSoup.find("p", attrs = {"class":"text-bold"}).findNext("p").text
                    # print("---------------- Recovered description Data-----------------\n" + str(tempData))

                    tempData = re.sub(" \s+", "", tempData)
                    tempData = re.sub("\n", "", tempData)
                    tempData = tempData.split(keyWord)
                    # print("---------------- Recovered description Data-----------------\n" + str(tempData))

                    # si encuentro el parrafo con los creditos con la estructura apropiada, dividido por ":"
                    if len(tempData) > 1:

                        # print("---------------- description after if -----------------\n" + str(tempData))
                        # tomo el primer elemento
                        tempData = tempData[0]
                        tempData = tempData.split(",")  
                        # print("---------------- description before compare -----------------\n" + str(tempData))

                        if len(tempData) == 1:

                            # print("---------------- description after split -----------------\n" + str(tempData))
                            # guardo en el diccionario el medio y las dimensiones
                            tempInfoDict["description"]["dimensions"] = tempData[0]
                            # print("---------------- description -----------------\n" + str(tempInfoDict["description"]))

                        elif len(tempData) == 2:

                            # print("---------------- description after split -----------------\n" + str(tempData))
                            # guardo en el diccionario el medio y las dimensiones
                            tempInfoDict["description"]["medium"] = tempData[0]
                            tempInfoDict["description"]["dimensions"] = tempData[1]
                            # print("---------------- description -----------------\n" + str(tempInfoDict["description"]))

                        elif len(tempData) > 2:

                            # print("---------------- description after split -----------------\n" + str(tempData))
                            # guardo en el diccionario el medio y las dimensiones
                            tempInfoDict["description"]["dimensions"] = tempData.pop()
                            tempInfoDict["description"]["medium"] = tempData
                            # print("---------------- description -----------------\n" + str(tempInfoDict["description"]))

                    # recuperando la descripcion de los creditos asociados con la obra.
                    tempData = letterSoup.find("p", attrs = {"class":"text-bold"}).findNext("p").text
                    # limpio y preparo lo que encontre
                    tempData = re.sub(" \s+", "", tempData)
                    tempData = re.sub("\n", "", tempData)
                    tempData = tempData.split(":")                        

                    # si encuentro el parrafo con los creditos con la estructura apropiada, dividido por ":"
                    if len(tempData) == 2:

                        # tomo el ultimo elemento
                        tempData = tempData[len(tempData)-1]
                        # print("---------------- Recovered credits Data-----------------\n" + str(tempData))
                        tempData = tempData.split(",")      

                        # guardo en el diccionario el poseedor y locacion de los creditos
                        tempInfoDict["credits"]["holder"] = tempData[0]
                        tempInfoDict["credits"]["place"] = tempData[1]
                        # print("---------------- credits -----------------\n" + str(tempInfoDict["credits"]))                    
                    
                    # transformo el dict a JSON.
                    jsonInfo = json.dumps(copy.deepcopy(tempInfoDict), ensure_ascii = False, indent = 4)

                    # guardo en un archivo el JSON de la descripcion.
                    with open(filePath, "w+", encoding = "utf-8") as file:
                        file.write(jsonInfo)
                        file.close()

                    # si no hay errores agrego un mensaje vacio para no danhar el dataframe
                    errList.append(None)
                    hasList.append(bool(True))
                    
                    # guardo un JSON creado en el CSV y en la carpeta
                    newData.append(jsonInfo)
                    counter += 1
                    # print(counter)
                    
####################################################################################################################
####################################################################################################################
################################### PROCESANDO UN ELEMENTO NO RECONOCIDO ###########################################
####################################################################################################################
####################################################################################################################                    

                # si lo que estoy describiendo no es ni carta ni obra
                elif linkSoup.find(soupTag, attrs = soupAttrs) == None or linkSoup.find(letterTag, attrs = letterAttrs) == None:
                
                    # print("this is weird!!!!!")
                    err = "Description of element NOT FOUND in URL:" + str(link) + "\n Request time: " + str(datetime.datetime.now())

                    # transformo el dict a JSON.
                    jsonInfo = json.dumps(copy.deepcopy(tempInfoDict), ensure_ascii = False, indent = 4)

                    # guardo en un archivo el JSON de la descripcion.
                    with open(filePath, "w+", encoding = "utf-8") as file:
                        file.write(jsonInfo)
                        file.close()

                    # si no hay errores agrego un mensaje vacio para no danhar el dataframe
                    errList.append(None)
                    hasList.append(bool(True))
                    
                    # guardo un JSON vacio en el CSV y en la carpeta
                    newData.append(jsonInfo)
                    counter += 1
                    # print(counter)        

    except Exception as e:
        print("In URL: " + link + "\nError: " + str(e))
        print("Status Code: " + str(linkReq.status_code))
        newData.append(copy.deepcopy(infoDictSchema))
        errList.append(e)
        hasList.append(bool(False))
# Out:
# Number of elements in Gallery: 1200
# Number of local folders for the Gallery: 1200
# Number of expected descriptions: 1200

# %%
print("Number of Description operations: " + str(counter))
print("Number of Descriptions: " + str(len(newData)))
print("Number of completed operations: " + str(len(hasList)))
print("Number of error reports: " + str(len(errList)))
# Out:
# Number of Description operations: 1200
# Number of Descriptions: 1200
# Number of completed operations: 1200
# Number of error reports: 1200

# %%
# actualizo el dataFrame para ver si hay errores
paintsFrame["HAS_DESCRIPTION"] = hasList
paintsFrame["ERR_DESCRIPTION"] = errList

# creo una nueva columna para guardar los los diccionarios/JSON dentro del CVS, tambien los guardo en JSON aparte!!!!
paintsFrame["DESCRIPTION"] = newData

# %%
# guardando los links en TXT y CSV para backup del proceso y control de calidad
galleryFile = "VanGoghGalleryIndex.csv"
dataFolder = "data"

# actualizando archivo original CSV
# si no existe el directorio
if not os.path.exists(dataFolder):
    
    os.makedirs(dataFolder)

# si existe el directorio
else: 
    
    # guardo el DataFrame segun las ultimas actualizaciones
    paintsFrame.to_csv(os.path.join(os.getcwd(), dataFolder, galleryFile), sep = ",", index = False, encoding = "utf-8", mode = "w")

# %%
# chequeo como va el dataframe de procesamiento
paintsFrame.info()
paintsFrame.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1200 entries, 0 to 1199
# Data columns (total 22 columns):
# ID                 1200 non-null object
# NAME               1200 non-null object
# ELEMENT_URL        1200 non-null object
# DOWNLOAD_URL       1200 non-null object
# HAS_ID             1200 non-null bool
# HAS_NAME           1200 non-null bool
# HAS_DESCRIPTION    1200 non-null bool
# HAS_DOWNLOAD       1200 non-null bool
# HAS_TAGS           1200 non-null object
# HAS_DATA           1200 non-null object
# HAS_RELATEDW       1200 non-null object
# ERR_ID             0 non-null object
# ERR_NAME           0 non-null object
# ERR_DESCRIPTION    0 non-null float64
# ERR_DOWNLOAD       168 non-null object
# ERR_TAGS           161 non-null object
# ERR_DATA           161 non-null object
# ERR_RELATEDW       0 non-null object
# DESCRIPTION        1200 non-null object
# TAGS               1200 non-null object
# DATA               1200 non-null object
# RELATEDW           400 non-null object
# dtypes: bool(4), float64(1), object(17)
# memory usage: 182.8+ KB
#            ID                                               NAME  \
# 0  s0005V1962                            The Potato Eaters, 1885
# 1  s0019V1962  Garden with Courting Couples: Square Saint-Pie...
# 2  s0027V1962                          The Langlois Bridge, 1888
# 3  s0029V1962                                    The Sower, 1888
# 4  s0031V1962                                   Sunflowers, 1889
#
#                                          ELEMENT_URL  \
# 0  https://vangoghmuseum.nl/en/collection/s0005V1962
# 1  https://vangoghmuseum.nl/en/collection/s0019V1962
# 2  https://vangoghmuseum.nl/en/collection/s0027V1962
# 3  https://vangoghmuseum.nl/en/collection/s0029V1962
# 4  https://vangoghmuseum.nl/en/collection/s0031V1962
#
#                                         DOWNLOAD_URL  HAS_ID  HAS_NAME  \
# 0  https://vangoghmuseum.nl/download/8bc21467-2e7...    True      True
# 1  https://vangoghmuseum.nl/download/12bd07b2-3c2...    True      True
# 2  https://vangoghmuseum.nl/download/c82c2fcd-90e...    True      True
# 3  https://vangoghmuseum.nl/download/61fbedad-1d6...    True      True
# 4  https://vangoghmuseum.nl/download/597e7189-79d...    True      True
#
#    HAS_DESCRIPTION  HAS_DOWNLOAD HAS_TAGS HAS_DATA  ... ERR_NAME  \
# 0             True          True     True     True  ...      NaN
# 1             True          True     True     True  ...      NaN
# 2             True          True     True     True  ...      NaN
# 3             True          True     True     True  ...      NaN
# 4             True          True     True     True  ...      NaN
#
#   ERR_DESCRIPTION ERR_DOWNLOAD  ERR_TAGS ERR_DATA ERR_RELATEDW  \
# 0             NaN          NaN       NaN      NaN          NaN
# 1             NaN          NaN       NaN      NaN          NaN
# 2             NaN          NaN       NaN      NaN          NaN
# 3             NaN          NaN       NaN      NaN          NaN
# 4             NaN          NaN       NaN      NaN          NaN
#
#                                          DESCRIPTION  \
# 0  {\n    "tittle": "The Potato Eaters",\n    "au...
# 1  {\n    "tittle": "Garden with Courting Couples...
# 2  {\n    "tittle": "The Langlois Bridge",\n    "...
# 3  {\n    "tittle": "The Sower",\n    "authorship...
# 4  {\n    "tittle": "Sunflowers",\n    "authorshi...
#
#                                                 TAGS  \
# 0  {\n    "tags": {\n        "references": [\n   ...
# 1  {\n    "tags": {\n        "references": [\n   ...
# 2  {\n    "tags": {\n        "references": [\n   ...
# 3  {\n    "tags": {\n        "references": [\n   ...
# 4  {\n    "tags": {\n        "references": [\n   ...
#
#                                                 DATA  \
# 0  {\n    "F_number": "F0082",\n    "JH_number": ...
# 1  {\n    "F_number": "F0314",\n    "JH_number": ...
# 2  {\n    "F_number": "F0400",\n    "JH_number": ...
# 3  {\n    "F_number": "F0451",\n    "JH_number": ...
# 4  {\n    "F_number": "F0458",\n    "JH_number": ...
#
#                                             RELATEDW
# 0  {\n    "relations": {\n        "references": [...
# 1  {\n    "relations": {\n        "references": [...
# 2  {\n    "relations": {\n        "references": [...
# 3  {\n    "relations": {\n        "references": [...
# 4  {\n    "relations": {\n        "references": [...
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Recuperar la lista de anotaciones del elemento en la galeria
#
# Con la columna de "ELEMENT_URL", "ID", "TAGS", "HAS_TAGS" y "ERR_TAGS" del dataFrame se hacen los siguientes pasos:
#
# - Revisar el enlace en "ELEMENT_URL" si el enlace esta activo se sigue adelante.
# - se recupera la seccion donde esta las anotaciones de busqueda del elemento, esta bajo el texto de "Search in the collection:".
# - se actualiza el dataframe para mantener la trasabilidad del proceso.
# - si las anotaciones ya estan, no se repite el trabajo.
#
# se supone que los subfolders de los elementos ya existen.

# %%
print("Number of Tags operations: " + str(counter))
print("Number of Search Tags: " + str(len(newData)))
print("Number of completed operations: " + str(len(hasList)))
print("Number of error reports: " + str(len(errList)))
# Out:
# Number of Tags operations: 1200
# Number of Search Tags: 1200
# Number of completed operations: 1200
# Number of error reports: 1200

# %%
# recorro el arreglo de enlaces habilitados para extraer la informacion
# creo las carpetas necesarias, si ya existen no las sobreescribo.
links = list(paintsFrame["ELEMENT_URL"])
# en este caso los IDs son los nombres de los folders en local
folders = list(paintsFrame["ID"])
# deberia haber un JSON en esta columna
tags = list(paintsFrame["TAGS"])
# lista de errores en el CSV
errors = list(paintsFrame["ERR_TAGS"])
# lista de existencia en el CSV
proofs = list(paintsFrame["HAS_TAGS"])

# variables de control de calidad del proceso, en este caso en las columnas, "HAS_DESCRIPTION", "ERR_DESCRIPTION"
errList = list()
hasList = list()

# lista donde se guarda la nueva informacion que se recupera de la descripcion y contenido de la obra.
newData = list()

# atributos de la busqueda en beatifulsoup
soupTag = "ul"
soupAttrs = {"class":"list-wrapping"}

# formato del diccionario para el JSON de persistencia para las anotaciones del elemento
dataDictSchema = {
    "tags": { # diccionario con la lista detallada de las anotaciones de la obra
        "references": list(), # la lista tiene el link y texto/tag asociado
    } 
}
# contador de la operacion
counter = 0

print("Number of elements in Gallery: " + str(len(links)))
print("Number of local folders for the Gallery: " + str(len(folders)))
print("Number of expected tags: " + str(len(tags)))

#inicio del ciclo para los enlaces, zip funciona para iterar 2 o mas arreglos al tiempo
for link, folder, tag, err, has in zip(links, folders, tags, errors, proofs):
    
    # chequeo si el enlace sirve para sacar la informacion
    try:
        # inicializo uuna variable temporal
        tempInfoDict = copy.deepcopy(dataDictSchema)

        # GET del URL
        linkReq = requests.get(link)

        # si el GET me responde bien con codigo 200
        if linkReq.status_code == 200:
            
            # creo path para cada elemento en la coleccion
            tempPaintFolder = os.path.join(workPath, folder)
            
            # creo el nombre del archivo JSON donde guardo la descripcion
            fileName = "tags_" + folder + ".json"
            filePath = os.path.join(tempPaintFolder, fileName)

            # si ya existe lo que voy a escribir
            if os.path.exists(tempPaintFolder) and os.path.exists(filePath):
                
                # solo lo tomo del dataframe y lo vuelvo a cargar
                jsonData = tag

                # si no hay errores agrego un mensaje vacio para no danhar el dataframe
                errList.append(err)
                hasList.append(has)           
                counter += 1
                # print(counter)  
            
            # si existe la carpeta y no existe el JSON, proceso la informacion de la descripcion
            elif os.path.exists(tempPaintFolder) and not os.path.exists(filePath):
                
                # parse del cuerpo del elemento de la coleccion
                linkSoup = BeautifulSoup(linkReq.content, "html.parser")
                
                # reviso que exista tags de busqueda en el elemento, hay algunas cartas que no lo tienene
                if linkSoup.find(soupTag, attrs = soupAttrs) != None:
                
                    # busco todos los elementos de tipo class="list-wrapping"
                    tagsSoup = linkSoup.find(soupTag, attrs = soupAttrs)
                
                    # saco la informacion que necesito de los tags de busqueda
                    tempData = tagsSoup.findAll("a", attrs = {"class":"button outline neutral text-titlecase"})

                    # lista de posibles enlaces externos
                    linkList = list()

                    # recopilo la lista dentro del elemento encontrado
                    for ref in tempData:#.findAll("a", attrs = {"class":"button outline neutral text-titlecase"}):

                        newLink = {"text":ref.text, "link":ref.get("href")} 
                        linkList.append(copy.deepcopy(newLink))

                    # guardo en el diccionario la lista de enlaces relevantes de las anotaciones.
                    tempInfoDict["tags"]["references"] = copy.deepcopy(linkList)

                    # transformo el dict a JSON.
                    jsonData = json.dumps(copy.deepcopy(tempInfoDict), ensure_ascii = False, indent = 4)

                    # guardo en un archivo el JSON de las anotaciones.
                    with open(filePath, "w+", encoding = "utf-8") as file:
                        file.write(jsonData)
                        file.close()

                    # si no hay errores agrego un mensaje vacio para no danhar el dataframe
                    errList.append(None)
                    hasList.append(bool(True))
                    counter += 1
                    # print(counter)  
                    
                # algunas cartas no tienen tags de busqueda, aqui marco cuales son
                elif linkSoup.find(soupTag, attrs = soupAttrs)== None:
                    
                    # print("this is weird, URL: " + str(link))
                    # transformo el dict a JSON.
                    jsonData = json.dumps(copy.deepcopy(tempInfoDict), ensure_ascii = False, indent = 4)

                    # guardo en un archivo el JSON de las anotaciones.
                    with open(filePath, "w+", encoding = "utf-8") as file:
                        file.write(jsonData)
                        file.close()

                    err = "Tags unavailable in URL: " + str(link) + "\n Request time: " + str(datetime.datetime.now())
                    
                    # si no hay errores agrego un mensaje vacio para no danhar el dataframe
                    errList.append(err)
                    hasList.append(bool(True))
                    counter += 1
                    # print(counter)
                     
            # agrego el JSON en una columna del dataframe
            newData.append(jsonData)
                    
    except Exception as e:
        print("In URL: " + link + "\nError: " + str(e))
        print("Status Code: " + str(linkReq.status_code))
        newData.append(copy.deepcopy(dataDictSchema))
        errList.append(e)
        hasList.append(bool(False))
# Out:
# Number of elements in Gallery: 1200
# Number of local folders for the Gallery: 1200
# Number of expected tags: 1200

# %%
# actualizo el dataFrame para ver si hay errores
paintsFrame["HAS_TAGS"] = hasList
paintsFrame["ERR_TAGS"] = errList

# creo una nueva columna para guardar las anotaciones en JSON dentro del CVS, tambien guardo JSON aparte!!!!
paintsFrame["TAGS"] = newData

# %%
# chequeo como va el dataframe de procesamiento
paintsFrame.info()
paintsFrame.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1200 entries, 0 to 1199
# Data columns (total 22 columns):
# ID                 1200 non-null object
# NAME               1200 non-null object
# ELEMENT_URL        1200 non-null object
# DOWNLOAD_URL       1200 non-null object
# HAS_ID             1200 non-null bool
# HAS_NAME           1200 non-null bool
# HAS_DESCRIPTION    1200 non-null bool
# HAS_DOWNLOAD       1200 non-null bool
# HAS_TAGS           1200 non-null bool
# HAS_DATA           1200 non-null object
# HAS_RELATEDW       1200 non-null object
# ERR_ID             0 non-null object
# ERR_NAME           0 non-null object
# ERR_DESCRIPTION    0 non-null float64
# ERR_DOWNLOAD       168 non-null object
# ERR_TAGS           161 non-null object
# ERR_DATA           161 non-null object
# ERR_RELATEDW       0 non-null object
# DESCRIPTION        1200 non-null object
# TAGS               1200 non-null object
# DATA               1200 non-null object
# RELATEDW           400 non-null object
# dtypes: bool(5), float64(1), object(16)
# memory usage: 174.6+ KB
#        ERR_DESCRIPTION
# count              0.0
# mean               NaN
# std                NaN
# min                NaN
# 25%                NaN
# 50%                NaN
# 75%                NaN
# max                NaN

# %%
# guardando los links en TXT y CSV para backup del proceso y control de calidad
galleryFile = "VanGoghGalleryIndex.csv"
dataFolder = "data"

# actualizando archivo original CSV
# si no existe el directorio
if not os.path.exists(dataFolder):
    
    os.makedirs(dataFolder)

# si existe el directorio
else: 
    
    # guardo el DataFrame segun las ultimas actualizaciones
    paintsFrame.to_csv(os.path.join(os.getcwd(), dataFolder, galleryFile), sep = ",", index = False, encoding = "utf-8", mode = "w")

# %% [markdown]
# ### Recuperar los datos de coleccion del elemento de la galeria
#
# Con la columna de "ELEMENT_URL", "ID", "DATA", "HAS_DATA" y "ERR_DATA" del dataFrame se hacen los siguientes pasos:
#
# - Revisar el enlace en "ELEMENT_URL" si el enlace esta activo se sigue adelante.
# - se recupera la seccion donde esta los datos de archivo del elemento.
# - se actualiza el dataframe para mantener la trasabilidad del proceso.
# - si la descripcion ya esta, no se repite el trabajo.
#
# se supone que los subfolders de los elementos ya existen.

# %%
# recorro el arreglode enlaces habilitados para extraer la informacion
# creo las carpetas necesarias, si ya existen no las sobreescribo.
links = list(paintsFrame["ELEMENT_URL"])
# en este caso los IDs son los nombres de los folders en local
folders = list(paintsFrame["ID"])
# deberia haber un JSON en esta columna
objects = list(paintsFrame["DATA"])
# lista de errores en el CSV
errors = list(paintsFrame["ERR_DATA"])
# lista de existencia en el CSV
proofs = list(paintsFrame["HAS_DATA"])

# variables de control de calidad del proceso, en este caso en las columnas, "ERR_DATA", "HAS_DATA"
errList = list()
hasList = list()

# lista donde se guarda la nueva informacion que se recupera de la descripcion y contenido de la obra.
newData = list()

# atributos de la busqueda en beatifulsoup
soupTag = "dl"
soupAttrs = {"class":"list-table compact"}

# formato del diccionario para el JSON de persistencia de la descripcion del elemento
dataDictSchema = {
    "F_number": str(), # numero de referencia F de la obra.
    "JH_number": str(), # numero de referencia JH de la obra.
    "Obj_number": str(), # numero de referencia del objeto de la obra.
    "L_number": dict(), # numero de referencia exter de la carta
    "dimensions": { # diccionario con las dimensiones basicas de la obra, canvas y marco.
        "canvas": str(),
    },
    "credits": { # diccionario para los creditos asociados con la obra.
        "holder": str(),
        "place": str(),
    },
}

# contador de la operacion
counter = 0

print("Number of elements in Gallery: " + str(len(links)))
print("Number of local folders for the Gallery: " + str(len(folders)))
print("Number of expected data objects: " + str(len(objects)))

#inicio del ciclo para los enlaces, zip funciona para iterar 2 arreglos al tiempo
for link, folder, obj, err, has in zip(links, folders, objects, errors, proofs):
    
    # chequeo si el enlace sirve para sacar la informacion
    try:
        # inicializo una variable temporal
        tempInfoDict = copy.deepcopy(dataDictSchema)

        # GET del URL
        linkReq = requests.get(link)

        # si el GET me responde bien con codigo 200
        if linkReq.status_code == 200:
            
            # creo path para cada elemento en la coleccion
            tempPaintFolder = os.path.join(workPath, folder)
            
            # creo el nombre del archivo JSON donde guardo la descripcion
            fileName = "data_" + folder + ".json"
            filePath = os.path.join(tempPaintFolder, fileName)

            if os.path.exists(tempPaintFolder) and os.path.exists(filePath):

                jsonInfo = obj

                # si no hay errores agrego un mensaje vacio para no danhar el dataframe
                errList.append(err)
                hasList.append(has)
                counter += 1
                # print(counter) 
            
            # si existe la carpeta y no existe el JSON, proceso la informacion de la descripcion
            elif os.path.exists(tempPaintFolder) and not os.path.exists(filePath):
                
                # parse del cuerpo del elemento de la coleccion
                linkSoup = BeautifulSoup(linkReq.content, "html.parser")
                
                # si no existe el objeto DATa dentro del elemento
                if linkSoup.find(soupTag, attrs = soupAttrs) == None:             
                
                    # transformo el dict a JSON.
                    jsonInfo = json.dumps(copy.deepcopy(tempInfoDict), ensure_ascii = False, indent = 4)

                    # guardo en un archivo el JSON de la descripcion.
                    with open(filePath, "w+", encoding = "utf-8") as file:
                        file.write(jsonInfo)
                        file.close()

                    # agrego el error y el contador para el dataframe
                    err = "Data Object unavailable in URL: " + str(link) + "\n Request time: " + str(datetime.datetime.now())
                    errList.append(err)
                    hasList.append(bool(False))         
                    counter += 1
                    # print(err)
                    # print(counter)
                    
                # hay ciertos elementos de la galeria que no tienen DATA
                elif linkSoup.find(soupTag, attrs = soupAttrs) != None:
                
                    # busco todos los elementos de tipo class="button dark-hover"
                    dataSoup = linkSoup.find(soupTag, attrs = soupAttrs)                 

                    # encuentro los titulos de las celdas
                    tempDataCol1 = dataSoup.findAll("dt", attrs = {"class":"text-titlecase"})

                    # encuentro los datos no-vacios de las celdas
                    # tempDataCol2 = dataSoup.findAll("dd", string = re.compile("^(?!\s*$).+"))
                    tempDataCol2 = list(d for d in dataSoup.findAll("dd") if len(d.get_text(strip=True)) > 0)
                    
                    # print("------------------------------------ DATA -----------------------------------")
                    # print(len(tempDataCol1) == len(tempDataCol2))
                    # print(len(tempDataCol1), len(tempDataCol2))
                    
                    if len(tempDataCol1) == len(tempDataCol2):

                        for data1, data2 in zip(tempDataCol1, tempDataCol2):

                            # si encuentro el numero F
                            if data1.text == "F-number":

                                # print("------------- F-number -------------------")
                                # print("----- Number Type ----- Number Value -----")
                                # print(data1, data2)
                                # limpio el dato de ser necesario y lo pongo en el diccionario
                                tempInfoDict["F_number"] = data2.text.strip(" ")

                            # si encuentro el numero JH
                            if data1.text == "JH-number":

                                # print("------------- F-number -------------------")
                                # print("----- Number Type ----- Number Value -----")
                                # print(data1, data2)
                                # limpio el dato de ser necesario y lo pongo en el diccionario
                                tempInfoDict["JH_number"] = data2.text.strip(" ")

                            # si encuentro el numero JH
                            if data1.text == "Object number":

                                # print("------------- F-number -------------------")
                                # print("----- Number Type ----- Number Value -----")
                                # print(data1, data2)
                                # limpio el dato de ser necesario y lo pongo en el diccionario
                                tempInfoDict["Obj_number"] = data2.text.strip(" ")
                                
                            # cuando se tiene una carta con referencia a su texto
                            if "Edition" in data1.text:

                                # print("------------- Edition 2009 -------------------")
                                # print("----- Number Type ----- Number Value -----")
                                # print(data1, data2)
                                tempData = data2.text
                                print(tempData, type(tempData))

                                # limpiando el texto de caracteres innecesarios
                                tempData = re.sub(" \s+", "", tempData)
                                tempData = re.sub("\n", " ", tempData)

                                print(tempData)
                                tempInfoDict["L_number"]["text"] = tempData

                                # lista de posibles enlaces externos
                                linkList = list()

                                tempData = data2.findAll("a")

                                # recopilo la lista dentro del elemento encontrado
                                for ref in tempData:

                                    newLink = {"text":ref.text, "link":ref.get("href")} 
                                    linkList.append(copy.deepcopy(newLink))

                                # guardo en el diccionario la lista de enlaces relevantes de las anotaciones.    
                                tempInfoDict["L_number"]["references"] = copy.deepcopy(linkList)
                                
                            # si encuentro los creditos de la obra
                            if "Credits" in data1.text:

                                tempData = data2.text.split(",")

                                if len(tempData) == 2:

                                    tempInfoDict["credits"]["holder"] = tempData[0]
                                    tempInfoDict["credits"]["place"] = tempData[1]
                            
                            # si encuentro las dimensiones de la obra
                            if data1.text == "Dimensions":

                                tempData = data2.text.split(",")
                                
                                if len(tempData) == 1:

                                    tempInfoDict["dimensions"]["canvas"] = tempData[0]
                                
                                if len(tempData) == 2:

                                    tempInfoDict["dimensions"]["canvas"] = tempData[0]
                                    tempInfoDict["dimensions"]["frame"] = tempData[1]                             
                    
                    # transformo el dict a JSON.
                    jsonInfo = json.dumps(copy.deepcopy(tempInfoDict), ensure_ascii = False, indent = 4)

                    # guardo en un archivo el JSON de la descripcion.
                    with open(filePath, "w+", encoding = "utf-8") as file:
                        file.write(jsonInfo)
                        file.close()

                    # si no hay errores agrego un mensaje vacio para no danhar el dataframe
                    errList.append(None)
                    hasList.append(bool(True))         
                    counter += 1
                    # print(counter)
                    
            # agrego el JSON en una columna del dataframe
            newData.append(jsonInfo)
                    
    except Exception as e:
        print("In URL: " + link + "\nError: " + str(e))
        print("Status Code: " + str(linkReq.status_code))
        newData.append(copy.deepcopy(dataDictSchema))
        errList.append(e)
        hasList.append(bool(False))
# Out:
# Number of elements in Gallery: 1200
# Number of local folders for the Gallery: 1200
# Number of expected data objects: 1200

# %%
print("Number of Data object operations: " + str(counter))
print("Number of Data objects: " + str(len(newData)))
print("Number of completed operations: " + str(len(hasList)))
print("Number of error reports: " + str(len(errList)))
# Out:
# Number of Data object operations: 1200
# Number of Data objects: 1200
# Number of completed operations: 1200
# Number of error reports: 1200

# %%
# actualizo el dataFrame para ver si hay errores
paintsFrame["HAS_DATA"] = hasList
paintsFrame["ERR_DATA"] = errList

# creo una nueva columna para guardar los diccionarios/JSON dentro del CVS, tambien los guardo en JSON aparte!!!!
paintsFrame["DATA"] = newData

# %%
# chequeo como va el dataframe de procesamiento
paintsFrame.info()
paintsFrame.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1200 entries, 0 to 1199
# Data columns (total 22 columns):
# ID                 1200 non-null object
# NAME               1200 non-null object
# ELEMENT_URL        1200 non-null object
# DOWNLOAD_URL       1200 non-null object
# HAS_ID             1200 non-null bool
# HAS_NAME           1200 non-null bool
# HAS_DESCRIPTION    1200 non-null bool
# HAS_DOWNLOAD       1200 non-null bool
# HAS_TAGS           1200 non-null bool
# HAS_DATA           1200 non-null bool
# HAS_RELATEDW       1200 non-null object
# ERR_ID             0 non-null object
# ERR_NAME           0 non-null object
# ERR_DESCRIPTION    0 non-null float64
# ERR_DOWNLOAD       168 non-null object
# ERR_TAGS           161 non-null object
# ERR_DATA           161 non-null object
# ERR_RELATEDW       0 non-null object
# DESCRIPTION        1200 non-null object
# TAGS               1200 non-null object
# DATA               1200 non-null object
# RELATEDW           400 non-null object
# dtypes: bool(6), float64(1), object(15)
# memory usage: 166.4+ KB
#            ID                                               NAME  \
# 0  s0005V1962                            The Potato Eaters, 1885
# 1  s0019V1962  Garden with Courting Couples: Square Saint-Pie...
# 2  s0027V1962                          The Langlois Bridge, 1888
# 3  s0029V1962                                    The Sower, 1888
# 4  s0031V1962                                   Sunflowers, 1889
#
#                                          ELEMENT_URL  \
# 0  https://vangoghmuseum.nl/en/collection/s0005V1962
# 1  https://vangoghmuseum.nl/en/collection/s0019V1962
# 2  https://vangoghmuseum.nl/en/collection/s0027V1962
# 3  https://vangoghmuseum.nl/en/collection/s0029V1962
# 4  https://vangoghmuseum.nl/en/collection/s0031V1962
#
#                                         DOWNLOAD_URL  HAS_ID  HAS_NAME  \
# 0  https://vangoghmuseum.nl/download/8bc21467-2e7...    True      True
# 1  https://vangoghmuseum.nl/download/12bd07b2-3c2...    True      True
# 2  https://vangoghmuseum.nl/download/c82c2fcd-90e...    True      True
# 3  https://vangoghmuseum.nl/download/61fbedad-1d6...    True      True
# 4  https://vangoghmuseum.nl/download/597e7189-79d...    True      True
#
#    HAS_DESCRIPTION  HAS_DOWNLOAD  HAS_TAGS  HAS_DATA  ... ERR_NAME  \
# 0             True          True      True      True  ...      NaN
# 1             True          True      True      True  ...      NaN
# 2             True          True      True      True  ...      NaN
# 3             True          True      True      True  ...      NaN
# 4             True          True      True      True  ...      NaN
#
#   ERR_DESCRIPTION ERR_DOWNLOAD  ERR_TAGS ERR_DATA ERR_RELATEDW  \
# 0             NaN          NaN       NaN      NaN          NaN
# 1             NaN          NaN       NaN      NaN          NaN
# 2             NaN          NaN       NaN      NaN          NaN
# 3             NaN          NaN       NaN      NaN          NaN
# 4             NaN          NaN       NaN      NaN          NaN
#
#                                          DESCRIPTION  \
# 0  {\n    "tittle": "The Potato Eaters",\n    "au...
# 1  {\n    "tittle": "Garden with Courting Couples...
# 2  {\n    "tittle": "The Langlois Bridge",\n    "...
# 3  {\n    "tittle": "The Sower",\n    "authorship...
# 4  {\n    "tittle": "Sunflowers",\n    "authorshi...
#
#                                                 TAGS  \
# 0  {\n    "tags": {\n        "references": [\n   ...
# 1  {\n    "tags": {\n        "references": [\n   ...
# 2  {\n    "tags": {\n        "references": [\n   ...
# 3  {\n    "tags": {\n        "references": [\n   ...
# 4  {\n    "tags": {\n        "references": [\n   ...
#
#                                                 DATA  \
# 0  {\n    "F_number": "F0082",\n    "JH_number": ...
# 1  {\n    "F_number": "F0314",\n    "JH_number": ...
# 2  {\n    "F_number": "F0400",\n    "JH_number": ...
# 3  {\n    "F_number": "F0451",\n    "JH_number": ...
# 4  {\n    "F_number": "F0458",\n    "JH_number": ...
#
#                                             RELATEDW
# 0  {\n    "relations": {\n        "references": [...
# 1  {\n    "relations": {\n        "references": [...
# 2  {\n    "relations": {\n        "references": [...
# 3  {\n    "relations": {\n        "references": [...
# 4  {\n    "relations": {\n        "references": [...
#
# [5 rows x 22 columns]

# %%
# guardando los links en TXT y CSV para backup del proceso y control de calidad
galleryFile = "VanGoghGalleryIndex.csv"
dataFolder = "data"

# actualizando archivo original CSV
# si no existe el directorio
if not os.path.exists(dataFolder):
    
    os.makedirs(dataFolder)

# si existe el directorio
else: 
    
    # guardo el DataFrame segun las ultimas actualizaciones
    paintsFrame.to_csv(os.path.join(os.getcwd(), dataFolder, galleryFile), sep = ",", index = False, encoding = "utf-8", mode = "w")

# %% [markdown]
# ### Recuperar el trabajo relacionado con el elemento de la galeria
#
# Con la columna de "ELEMENT_URL", "ID", "RELATEDW", "HAS_RELATEDW" y "ERR_RELATEDW" del dataFrame se hacen los siguientes pasos:
#
# - Revisar el enlace en "ELEMENT_URL" si el enlace esta activo se sigue adelante.
# - si existe, se recupera la seccion donde esta el trabajo relacionado del elemento.
# - se actualiza el dataframe para mantener la trasabilidad del proceso.
# - si la descripcion ya esta, no se repite el trabajo.
#
# se supone que los subfolders de los elementos ya existen.

# %%
# recorro el arreglo de enlaces habilitados para extraer la informacion
# creo las carpetas necesarias, si ya existen no las sobreescribo.
links = list(paintsFrame["ELEMENT_URL"])
# en este caso los IDs son los nombres de los folders en local
folders = list(paintsFrame["ID"])
# deberia haber un JSON en esta columna
relationships = list(paintsFrame["RELATEDW"])
# lista de errores en el CSV
errors = list(paintsFrame["ERR_RELATEDW"])
# lista de existencia en el CSV
proofs = list(paintsFrame["HAS_RELATEDW"])

# variables de control de calidad del proceso, en este caso en las columnas, "HAS_DESCRIPTION", "ERR_DESCRIPTION"
errList = list()
hasList = list()

# lista donde se guarda la nueva informacion que se recupera de la descripcion y contenido de la obra.
newData = list()

# atributos de la busqueda en beatifulsoup
soupTag = "section"
soupAttrs = {"class":"page-unit"}

letterTag = "div"
letterAttrs = {"id":"info", "class":"set-overview-body has-footer"}

# formato del diccionario para el JSON de persistencia de la descripcion del elemento
dataDictSchema = {
    "relations": { # diccionario con la lista detallada de las anotaciones de la obra
        "references": list(), # la lista tiene el link y texto/tag asociado
    }
}

# contador de la operacion
counter = 0

print("Number of elements in Gallery: " + str(len(links)))
print("Number of local folders for the Gallery: " + str(len(folders)))
print("Number of expected related work elements: " + str(len(relationships)))

#inicio del ciclo para los enlaces, zip funciona para iterar 2 arreglos al tiempo
for link, folder, relation, err, has in zip(links, folders, relationships, errors, proofs):
    
    print("-------------------- RELATED WORK No. " + str(counter+1) + " ----------------------\nlink: " + str(link))
    # chequeo si el enlace sirve para sacar la informacion
    try:
        # inicializo uuna variable temporal
        tempInfoDict = copy.deepcopy(dataDictSchema)

        # GET del URL
        linkReq = requests.get(link)

        # si el GET me responde bien con codigo 200
        if linkReq.status_code == 200:
            
            print("200 ok")
            # creo path para cada elemento en la coleccion
            tempPaintFolder = os.path.join(workPath, folder)
            
            # creo el nombre del archivo JSON donde guardo la descripcion
            fileName = "relw_" + folder + ".json"
            filePath = os.path.join(tempPaintFolder, fileName)
            
            # si ya existe el archivo JSON
            if os.path.exists(tempPaintFolder) and os.path.exists(filePath):

                jsonInfo = relation

                # si no hay errores agrego un mensaje vacio para no danhar el dataframe
                errList.append(err)
                hasList.append(has)              
                counter += 1
                print("Element No. " + str(counter) +" already there!!!")
            
            # si existe la carpeta y no existe el JSON, proceso la informacion de la descripcion
            elif os.path.exists(tempPaintFolder) and not os.path.exists(filePath):
                
                print("tempPaintFolder exists and JSON does not exists")
                
                # parse del cuerpo del elemento de la coleccion
                linkSoup = BeautifulSoup(linkReq.content, "html.parser")

                # si existen busco todos los elementos de tipo class="page-unit" en el carrusel de la obra
                if linkSoup.find(soupTag, attrs = soupAttrs) != None:
                    
                    print("Painting != none OK")

                    workSoup = linkSoup.find(soupTag, attrs = soupAttrs)
                    
                    # busco la lista de trabajo relacionado de obras
                    if workSoup.find("div", attrs = {"class":"carrousel-wrapper component"}) != None:
                                
                        # lista de posibles enlaces externos
                        linkList = list()
                        
                        # si no existe trabajo relacionado
                        if len(workSoup.findAll("figure")) == 0:

                            jsonInfo = json.dumps(copy.deepcopy(tempInfoDict), ensure_ascii = False, indent = 4)

                            with open(filePath, "w+", encoding = "utf-8") as file:
                                file.write(jsonInfo)
                                file.close()
                                
                            # si no hay errores agrego un mensaje vacio para no danhar el dataframe
                            errList.append(None)
                            hasList.append(bool(True))

                            # agrego el JSON en una columna del dataframe
                            newData.append(jsonInfo)
                            counter += 1
                            print("there is NO related work for this painting, operation No.: " + str(counter))
                            
                        elif len(workSoup.findAll("figure")) > 0:
                        
                            tempData = workSoup.findAll("figure", attrs = {"class":"carrousel-item"})

                            for rdata in tempData:
                                
                                tempLink = rdata.find("a")
                                # reconstruyo el enlace completo
                                tempLink = urllib.parse.urljoin(paintsRoot, tempLink.get("href"))
                                
                                # recupero el nombre del enlace
                                tempName = rdata.find("figcaption").text
                                tempName = re.sub(" \s+", "", tempName)
                                tempName = re.sub("\n", "", tempName)
                                
                                newLink = {"text":tempName, "link":tempLink}
                                linkList.append(copy.deepcopy(newLink))
                                
                            # guardo en el diccionario la lista de enlaces relevantes de la obra.
                            tempInfoDict["relations"]["references"] = copy.deepcopy(linkList)

                            # transformo el dict a JSON.
                            jsonInfo = json.dumps(copy.deepcopy(tempInfoDict), ensure_ascii = False, indent = 4)
                
                            # guardo en un archivo el JSON de la descripcion.
                            with open(filePath, "w+", encoding = "utf-8") as file:
                                file.write(jsonInfo)
                                file.close()

                            # si no hay errores agrego un mensaje vacio para no danhar el dataframe
                            errList.append(None)
                            hasList.append(bool(True))

                            # agrego el JSON en una columna del dataframe
                            newData.append(jsonInfo)
                            counter += 1
                            print("New related work element created for this painting, operation No.: " + str(counter))
                        
                # si existen las cartas relacionadas se buscan los elementos dentro de la division
                if linkSoup.find(letterTag, attrs = letterAttrs) != None:

                    print("Letter != none OK")
                    
                    workSoup = linkSoup.find(letterTag, attrs = letterAttrs)
                                        
                    # busco la lista de trabajo relacionado de obras
                    # if workSoup.find("ul", attrs = {"class":["cols mmin-cols-2up mm-cols-3up mxl-cols-4up", "cols mm-cols-2up ml-cols-3up"]}) != None:
                    if workSoup.find("ul", attrs = {"class":["cols mm-cols-2up ml-cols-3up", "cols mmin-cols-2up mm-cols-3up mxl-cols-4up"]}) != None:
                        
                        # cols mm-cols-2up ml-cols-3up, cols mmin-cols-2up mm-cols-3up mxl-cols-4up
                        # lista de posibles enlaces externos
                        print("if ul != None")
                        linkList = list()
                        
                        # si no existe trabajo relacionado
                        if len(workSoup.findAll("a")) == 0:
                            
                            jsonInfo = json.dumps(copy.deepcopy(tempInfoDict), ensure_ascii = False, indent = 4)

                            with open(filePath, "w+", encoding = "utf-8") as file:
                                file.write(jsonInfo)
                                file.close()

                            # si no hay errores agrego un mensaje vacio para no danhar el dataframe
                            errList.append(None)
                            hasList.append(bool(True))
                            
                            # agrego el JSON en una columna del dataframe
                            newData.append(jsonInfo)
                            counter += 1
                            print("there is NO related work for this letter, operation No.: " + str(counter))

                        elif len(workSoup.findAll("a")) > 0:
                            
                            tempData = workSoup.findAll("a")

                            for rdata in tempData:

                                # recupero el nombre del enlace
                                tempName = None
                                
                                if rdata.find("img", attrs = {"class":"image-lazy"}) != None:
                                
                                    tempName = rdata.find("img", attrs = {"class":"image-lazy"}).get("alt")
                                    tempName = re.sub(" \s+", "", tempName)
                                    tempName = re.sub("\n", "", tempName)

                                    # reconstruyo el enlace completo
                                    tempLink = urllib.parse.urljoin(paintsRoot, rdata.get("href"))

                                    newLink = {"text":tempName, "link":tempLink}
                                    linkList.append(copy.deepcopy(newLink))

                            # guardo en el diccionario la lista de enlaces relevantes de la obra.
                            tempInfoDict["relations"]["references"] = copy.deepcopy(linkList)

                            # transformo el dict a JSON.
                            jsonInfo = json.dumps(copy.deepcopy(tempInfoDict), ensure_ascii = False, indent = 4)                        
                            
                            with open(filePath, "w+", encoding = "utf-8") as file:
                                file.write(jsonInfo)
                                file.close()

                            # si no hay errores agrego un mensaje vacio para no danhar el dataframe
                            errList.append(None)
                            hasList.append(bool(True))
                            
                            # agrego el JSON en una columna del dataframe
                            newData.append(jsonInfo)
                            counter += 1
                            print("New letter related work element created, assigned No. is: " + str(counter))
                
                # si el elemento no tiene la estructura esperada
                if linkSoup.find(soupTag, attrs = soupAttrs) == None and linkSoup.find(letterTag, attrs = letterAttrs) == None:
                # else:
                    
                    # guardo en el diccionario la lista de enlaces relevantes de la obra.
                    print("this link is weird!!!... ")# + str(link))
                    tempInfoDict["relations"]["references"] = list()

                    # transformo el dict a JSON.
                    jsonInfo = json.dumps(copy.deepcopy(tempInfoDict), ensure_ascii = False, indent = 4)

                    # guardo en un archivo el JSON de la descripcion.
                    with open(filePath, "w+", encoding = "utf-8") as file:
                        file.write(jsonInfo)
                        file.close()

                    err = "Related work is unavailable in URL: " + str(link) + "\n Request time: " + str(datetime.datetime.now())

                    # # si no hay errores agrego un mensaje vacio para no danhar el dataframe
                    errList.append(err)
                    hasList.append(bool(False))
                    # agrego el JSON en una columna del dataframe
                    newData.append(jsonInfo)
                    counter += 1
                    print("Operation No. " + str(counter) + " couldnt find related work element")
                    
    except Exception as e:
        print("In URL: " + link + "\nError: " + str(e))
        print("Status Code: " + str(linkReq.status_code))
        newData.append(copy.deepcopy(dataDictSchema))
        errList.append(e)
        hasList.append(bool(False))
# Out:
# Number of elements in Gallery: 1200
# Number of local folders for the Gallery: 1200
# Number of expected related work elements: 1200
# -------------------- RELATED WORK No. 1 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0005V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 1
# -------------------- RELATED WORK No. 2 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0019V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 2
# -------------------- RELATED WORK No. 3 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0027V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 3 couldnt find related work element
# -------------------- RELATED WORK No. 4 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0029V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 4 couldnt find related work element
# -------------------- RELATED WORK No. 5 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0031V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 5 couldnt find related work element
# -------------------- RELATED WORK No. 6 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0032V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 6 couldnt find related work element
# -------------------- RELATED WORK No. 7 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0047V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 7 couldnt find related work element
# -------------------- RELATED WORK No. 8 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0022V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 8 couldnt find related work element
# -------------------- RELATED WORK No. 9 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0049V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 9 couldnt find related work element
# -------------------- RELATED WORK No. 10 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0176V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 10 couldnt find related work element
# -------------------- RELATED WORK No. 11 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0050V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 11 couldnt find related work element
# -------------------- RELATED WORK No. 12 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0106V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 12 couldnt find related work element
# -------------------- RELATED WORK No. 13 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0149V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 13 couldnt find related work element
# -------------------- RELATED WORK No. 14 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0195V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 14 couldnt find related work element
# -------------------- RELATED WORK No. 15 ----------------------
# link: https://vangoghmuseum.nl/en/collection/d0378V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 15 couldnt find related work element
# -------------------- RELATED WORK No. 16 ----------------------
# link: https://vangoghmuseum.nl/en/collection/d0386M1977
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 16 couldnt find related work element
# -------------------- RELATED WORK No. 17 ----------------------
# link: https://vangoghmuseum.nl/en/collection/d0423V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 17 couldnt find related work element
# -------------------- RELATED WORK No. 18 ----------------------
# link: https://vangoghmuseum.nl/en/collection/d0364V1968
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 18 couldnt find related work element
# -------------------- RELATED WORK No. 19 ----------------------
# link: https://vangoghmuseum.nl/en/collection/d0171V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 19 couldnt find related work element
# -------------------- RELATED WORK No. 20 ----------------------
# link: https://vangoghmuseum.nl/en/collection/d0420V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 20 couldnt find related work element
# -------------------- RELATED WORK No. 21 ----------------------
# link: https://vangoghmuseum.nl/en/collection/d0344V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 21 couldnt find related work element
# -------------------- RELATED WORK No. 22 ----------------------
# link: https://vangoghmuseum.nl/en/collection/d0222V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 22 couldnt find related work element
# -------------------- RELATED WORK No. 23 ----------------------
# link: https://vangoghmuseum.nl/en/collection/d0337V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 23 couldnt find related work element
# -------------------- RELATED WORK No. 24 ----------------------
# link: https://vangoghmuseum.nl/en/collection/d0340V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 24 couldnt find related work element
# -------------------- RELATED WORK No. 25 ----------------------
# link: https://vangoghmuseum.nl/en/collection/d0446V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 25 couldnt find related work element
# -------------------- RELATED WORK No. 26 ----------------------
# link: https://vangoghmuseum.nl/en/collection/d1172S2012
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 26 couldnt find related work element
# -------------------- RELATED WORK No. 27 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0137V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 27 couldnt find related work element
# -------------------- RELATED WORK No. 28 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0053V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 28 couldnt find related work element
# -------------------- RELATED WORK No. 29 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0129V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 29 couldnt find related work element
# -------------------- RELATED WORK No. 30 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0130V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 30 couldnt find related work element
# -------------------- RELATED WORK No. 31 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0003V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 31 couldnt find related work element
# -------------------- RELATED WORK No. 32 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0100V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 32
# -------------------- RELATED WORK No. 33 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0073V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 33 couldnt find related work element
# -------------------- RELATED WORK No. 34 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0096V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 34
# -------------------- RELATED WORK No. 35 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0052V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 35 couldnt find related work element
# -------------------- RELATED WORK No. 36 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0138V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 36
# -------------------- RELATED WORK No. 37 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0060V1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 37 couldnt find related work element
# -------------------- RELATED WORK No. 38 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0060V1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 38
# -------------------- RELATED WORK No. 39 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0084V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 39
# -------------------- RELATED WORK No. 40 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0132V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 40
# -------------------- RELATED WORK No. 41 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0007V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 41
# -------------------- RELATED WORK No. 42 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0009V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 42 couldnt find related work element
# -------------------- RELATED WORK No. 43 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0135V1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 43
# -------------------- RELATED WORK No. 44 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0062V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 44
# -------------------- RELATED WORK No. 45 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0087V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 45 couldnt find related work element
# -------------------- RELATED WORK No. 46 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0002V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 46 couldnt find related work element
# -------------------- RELATED WORK No. 47 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0151V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 47
# -------------------- RELATED WORK No. 48 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0153V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 48
# -------------------- RELATED WORK No. 49 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0150V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 49
# -------------------- RELATED WORK No. 50 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0070V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 50 couldnt find related work element
# -------------------- RELATED WORK No. 51 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0154V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 51
# -------------------- RELATED WORK No. 52 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0071V1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 52 couldnt find related work element
# -------------------- RELATED WORK No. 53 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0071V1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 53
# -------------------- RELATED WORK No. 54 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0001V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 54 couldnt find related work element
# -------------------- RELATED WORK No. 55 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0152V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 55
# -------------------- RELATED WORK No. 56 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0008V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 56 couldnt find related work element
# -------------------- RELATED WORK No. 57 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0141M1977
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 57 couldnt find related work element
# -------------------- RELATED WORK No. 58 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0139V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 58
# -------------------- RELATED WORK No. 59 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0452S1995
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 59 couldnt find related work element
# -------------------- RELATED WORK No. 60 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0072V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 60
# -------------------- RELATED WORK No. 61 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0343V1966
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 61 couldnt find related work element
# -------------------- RELATED WORK No. 62 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0006V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 62
# -------------------- RELATED WORK No. 63 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0058V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 63 couldnt find related work element
# -------------------- RELATED WORK No. 64 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0069V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 64
# -------------------- RELATED WORK No. 65 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0010V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 65 couldnt find related work element
# -------------------- RELATED WORK No. 66 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0054V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 66 couldnt find related work element
# -------------------- RELATED WORK No. 67 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0136V1973
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 67 couldnt find related work element
# -------------------- RELATED WORK No. 68 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0068V1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 68 couldnt find related work element
# -------------------- RELATED WORK No. 69 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0068V1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 69
# -------------------- RELATED WORK No. 70 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0158V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 70 couldnt find related work element
# -------------------- RELATED WORK No. 71 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0160V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 71
# -------------------- RELATED WORK No. 72 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0140V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 72 couldnt find related work element
# -------------------- RELATED WORK No. 73 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0061V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 73
# -------------------- RELATED WORK No. 74 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0059V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 74
# -------------------- RELATED WORK No. 75 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0143V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 75
# -------------------- RELATED WORK No. 76 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0159V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 76
# -------------------- RELATED WORK No. 77 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0162V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 77 couldnt find related work element
# -------------------- RELATED WORK No. 78 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0085V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 78 couldnt find related work element
# -------------------- RELATED WORK No. 79 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0083V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 79 couldnt find related work element
# -------------------- RELATED WORK No. 80 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0090V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 80
# -------------------- RELATED WORK No. 81 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0093V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 81 couldnt find related work element
# -------------------- RELATED WORK No. 82 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0091V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 82
# -------------------- RELATED WORK No. 83 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0074V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 83
# -------------------- RELATED WORK No. 84 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0056V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 84
# -------------------- RELATED WORK No. 85 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0089V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 85
# -------------------- RELATED WORK No. 86 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0202V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 86
# -------------------- RELATED WORK No. 87 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0101V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 87
# -------------------- RELATED WORK No. 88 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0103V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 88
# -------------------- RELATED WORK No. 89 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0102V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 89
# -------------------- RELATED WORK No. 90 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0199V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 90
# -------------------- RELATED WORK No. 91 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0200V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 91
# -------------------- RELATED WORK No. 92 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0075V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 92
# -------------------- RELATED WORK No. 93 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0201V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 93
# -------------------- RELATED WORK No. 94 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0178V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 94
# -------------------- RELATED WORK No. 95 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0064V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 95
# -------------------- RELATED WORK No. 96 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0012V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 96
# -------------------- RELATED WORK No. 97 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0092V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 97 couldnt find related work element
# -------------------- RELATED WORK No. 98 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0177V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 98 couldnt find related work element
# -------------------- RELATED WORK No. 99 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0182V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 99
# -------------------- RELATED WORK No. 100 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0180V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 100 couldnt find related work element
# -------------------- RELATED WORK No. 101 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0144V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 101 couldnt find related work element
# -------------------- RELATED WORK No. 102 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0131V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 102
# -------------------- RELATED WORK No. 103 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0011V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 103 couldnt find related work element
# -------------------- RELATED WORK No. 104 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0122V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 104 couldnt find related work element
# -------------------- RELATED WORK No. 105 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0142V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 105 couldnt find related work element
# -------------------- RELATED WORK No. 106 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0013V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 106
# -------------------- RELATED WORK No. 107 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0161V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 107 couldnt find related work element
# -------------------- RELATED WORK No. 108 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0133M1970
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 108 couldnt find related work element
# -------------------- RELATED WORK No. 109 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0155V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 109 couldnt find related work element
# -------------------- RELATED WORK No. 110 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0097V1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 110 couldnt find related work element
# -------------------- RELATED WORK No. 111 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0097V1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 111
# -------------------- RELATED WORK No. 112 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0126V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 112 couldnt find related work element
# -------------------- RELATED WORK No. 113 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0098V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 113
# -------------------- RELATED WORK No. 114 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0185V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 114
# -------------------- RELATED WORK No. 115 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0094V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 115
# -------------------- RELATED WORK No. 116 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0077V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 116 couldnt find related work element
# -------------------- RELATED WORK No. 117 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0157V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 117
# -------------------- RELATED WORK No. 118 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0156V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 118
# -------------------- RELATED WORK No. 119 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0123V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 119
# -------------------- RELATED WORK No. 120 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0128V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 120
# -------------------- RELATED WORK No. 121 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0055V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 121 couldnt find related work element
# -------------------- RELATED WORK No. 122 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0086V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 122 couldnt find related work element
# -------------------- RELATED WORK No. 123 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0078V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 123 couldnt find related work element
# -------------------- RELATED WORK No. 124 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0080V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 124 couldnt find related work element
# -------------------- RELATED WORK No. 125 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0066V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 125
# -------------------- RELATED WORK No. 126 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0197V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 126 couldnt find related work element
# -------------------- RELATED WORK No. 127 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0018V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 127 couldnt find related work element
# -------------------- RELATED WORK No. 128 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0134V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 128 couldnt find related work element
# -------------------- RELATED WORK No. 129 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0127V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 129 couldnt find related work element
# -------------------- RELATED WORK No. 130 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0179V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 130 couldnt find related work element
# -------------------- RELATED WORK No. 131 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0181V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 131
# -------------------- RELATED WORK No. 132 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0063V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 132
# -------------------- RELATED WORK No. 133 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0183V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 133 couldnt find related work element
# -------------------- RELATED WORK No. 134 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0193V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 134
# -------------------- RELATED WORK No. 135 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0186V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 135
# -------------------- RELATED WORK No. 136 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0020V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 136
# -------------------- RELATED WORK No. 137 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0057V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 137
# -------------------- RELATED WORK No. 138 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0016V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 138 couldnt find related work element
# -------------------- RELATED WORK No. 139 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0015V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 139
# -------------------- RELATED WORK No. 140 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0014V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 140
# -------------------- RELATED WORK No. 141 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0065V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 141 couldnt find related work element
# -------------------- RELATED WORK No. 142 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0021V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 142 couldnt find related work element
# -------------------- RELATED WORK No. 143 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0165V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 143 couldnt find related work element
# -------------------- RELATED WORK No. 144 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0017V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 144 couldnt find related work element
# -------------------- RELATED WORK No. 145 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0115V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 145
# -------------------- RELATED WORK No. 146 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0114V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 146
# -------------------- RELATED WORK No. 147 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0116V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 147
# -------------------- RELATED WORK No. 148 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0082V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 148 couldnt find related work element
# -------------------- RELATED WORK No. 149 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0121V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 149 couldnt find related work element
# -------------------- RELATED WORK No. 150 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0023V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 150
# -------------------- RELATED WORK No. 151 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0004V1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 151 couldnt find related work element
# -------------------- RELATED WORK No. 152 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0004V1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 152 couldnt find related work element
# -------------------- RELATED WORK No. 153 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0119V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 153 couldnt find related work element
# -------------------- RELATED WORK No. 154 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0145V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 154 couldnt find related work element
# -------------------- RELATED WORK No. 155 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0184V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 155 couldnt find related work element
# -------------------- RELATED WORK No. 156 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0110V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 156 couldnt find related work element
# -------------------- RELATED WORK No. 157 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0024V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 157
# -------------------- RELATED WORK No. 158 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0025V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 158
# -------------------- RELATED WORK No. 159 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0039V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 159
# -------------------- RELATED WORK No. 160 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0034V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 160 couldnt find related work element
# -------------------- RELATED WORK No. 161 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0037V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 161 couldnt find related work element
# -------------------- RELATED WORK No. 162 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0146V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 162 couldnt find related work element
# -------------------- RELATED WORK No. 163 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0030V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 163 couldnt find related work element
# -------------------- RELATED WORK No. 164 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0028V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 164 couldnt find related work element
# -------------------- RELATED WORK No. 165 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0117V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 165 couldnt find related work element
# -------------------- RELATED WORK No. 166 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0067V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 166 couldnt find related work element
# -------------------- RELATED WORK No. 167 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0167V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 167 couldnt find related work element
# -------------------- RELATED WORK No. 168 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0164V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 168 couldnt find related work element
# -------------------- RELATED WORK No. 169 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0048V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 169 couldnt find related work element
# -------------------- RELATED WORK No. 170 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0038V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 170 couldnt find related work element
# -------------------- RELATED WORK No. 171 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0036V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 171 couldnt find related work element
# -------------------- RELATED WORK No. 172 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0163V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 172 couldnt find related work element
# -------------------- RELATED WORK No. 173 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0113V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 173 couldnt find related work element
# -------------------- RELATED WORK No. 174 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0166V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 174 couldnt find related work element
# -------------------- RELATED WORK No. 175 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0257V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 175 couldnt find related work element
# -------------------- RELATED WORK No. 176 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0026V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 176
# -------------------- RELATED WORK No. 177 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0035V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 177 couldnt find related work element
# -------------------- RELATED WORK No. 178 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0040V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 178 couldnt find related work element
# -------------------- RELATED WORK No. 179 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0033V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 179 couldnt find related work element
# -------------------- RELATED WORK No. 180 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0190V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 180 couldnt find related work element
# -------------------- RELATED WORK No. 181 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0194V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# New related work element created for this painting, operation No.: 181
# -------------------- RELATED WORK No. 182 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0124V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 182 couldnt find related work element
# -------------------- RELATED WORK No. 183 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0120V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 183 couldnt find related work element
# -------------------- RELATED WORK No. 184 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0189V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 184 couldnt find related work element
# -------------------- RELATED WORK No. 185 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0147V1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 185 couldnt find related work element
# -------------------- RELATED WORK No. 186 ----------------------
# link: https://vangoghmuseum.nl/en/collection/s0168V1962
# 200 ok
# ...
# -------------------- RELATED WORK No. 1135 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0635bV1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1135 couldnt find related work element
# -------------------- RELATED WORK No. 1136 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0652cV1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# Letter != none OK
# if ul != None
# New letter related work element created, assigned No. is: 1136
# -------------------- RELATED WORK No. 1137 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0652dV1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# Letter != none OK
# if ul != None
# New letter related work element created, assigned No. is: 1137
# -------------------- RELATED WORK No. 1138 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0653bV1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# Letter != none OK
# if ul != None
# New letter related work element created, assigned No. is: 1138
# -------------------- RELATED WORK No. 1139 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0653cV1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# Letter != none OK
# if ul != None
# New letter related work element created, assigned No. is: 1139
# -------------------- RELATED WORK No. 1140 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0655bV1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# Letter != none OK
# if ul != None
# New letter related work element created, assigned No. is: 1140
# -------------------- RELATED WORK No. 1141 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0701bV1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# Letter != none OK
# if ul != None
# New letter related work element created, assigned No. is: 1141
# -------------------- RELATED WORK No. 1142 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0704bV1962
# 200 ok
# tempPaintFolder exists and JSON does not exists
# Painting != none OK
# Letter != none OK
# if ul != None
# New letter related work element created, assigned No. is: 1142
# -------------------- RELATED WORK No. 1143 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0599V1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1143 couldnt find related work element
# -------------------- RELATED WORK No. 1144 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0599V1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1144 couldnt find related work element
# -------------------- RELATED WORK No. 1145 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0299bV1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1145 couldnt find related work element
# -------------------- RELATED WORK No. 1146 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0299bV1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1146 couldnt find related work element
# -------------------- RELATED WORK No. 1147 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0359aV1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1147 couldnt find related work element
# -------------------- RELATED WORK No. 1148 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0359aV1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1148 couldnt find related work element
# -------------------- RELATED WORK No. 1149 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0520bV1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1149 couldnt find related work element
# -------------------- RELATED WORK No. 1150 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0520bV1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1150 couldnt find related work element
# -------------------- RELATED WORK No. 1151 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0547bV1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1151 couldnt find related work element
# -------------------- RELATED WORK No. 1152 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0547bV1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1152 couldnt find related work element
# -------------------- RELATED WORK No. 1153 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0565bV1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1153 couldnt find related work element
# -------------------- RELATED WORK No. 1154 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0565bV1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1154 couldnt find related work element
# -------------------- RELATED WORK No. 1155 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0652aV1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1155 couldnt find related work element
# -------------------- RELATED WORK No. 1156 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0652aV1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1156 couldnt find related work element
# -------------------- RELATED WORK No. 1157 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0652cV1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1157 couldnt find related work element
# -------------------- RELATED WORK No. 1158 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0652dV1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1158 couldnt find related work element
# -------------------- RELATED WORK No. 1159 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0652dV1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1159 couldnt find related work element
# -------------------- RELATED WORK No. 1160 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b8389aV2006r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1160 couldnt find related work element
# -------------------- RELATED WORK No. 1161 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b8389aV2006v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1161 couldnt find related work element
# -------------------- RELATED WORK No. 1162 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b8389bV2006r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1162 couldnt find related work element
# -------------------- RELATED WORK No. 1163 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b8389bV2006v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1163 couldnt find related work element
# -------------------- RELATED WORK No. 1164 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0242aV1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1164 couldnt find related work element
# -------------------- RELATED WORK No. 1165 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0242aV1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1165 couldnt find related work element
# -------------------- RELATED WORK No. 1166 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0242dV1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1166 couldnt find related work element
# -------------------- RELATED WORK No. 1167 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0242dV1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1167 couldnt find related work element
# -------------------- RELATED WORK No. 1168 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0243aV1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1168 couldnt find related work element
# -------------------- RELATED WORK No. 1169 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0243aV1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1169 couldnt find related work element
# -------------------- RELATED WORK No. 1170 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0243bV1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1170 couldnt find related work element
# -------------------- RELATED WORK No. 1171 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0243bV1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1171 couldnt find related work element
# -------------------- RELATED WORK No. 1172 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0146V1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1172 couldnt find related work element
# -------------------- RELATED WORK No. 1173 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0146V1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1173 couldnt find related work element
# -------------------- RELATED WORK No. 1174 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0258V1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1174 couldnt find related work element
# -------------------- RELATED WORK No. 1175 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0258V1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1175 couldnt find related work element
# -------------------- RELATED WORK No. 1176 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0652cV1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1176 couldnt find related work element
# -------------------- RELATED WORK No. 1177 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0012V1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1177 couldnt find related work element
# -------------------- RELATED WORK No. 1178 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0012V1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1178 couldnt find related work element
# -------------------- RELATED WORK No. 1179 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0013V1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1179 couldnt find related work element
# -------------------- RELATED WORK No. 1180 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0013V1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1180 couldnt find related work element
# -------------------- RELATED WORK No. 1181 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0016V1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1181 couldnt find related work element
# -------------------- RELATED WORK No. 1182 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0016V1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1182 couldnt find related work element
# -------------------- RELATED WORK No. 1183 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0020V1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1183 couldnt find related work element
# -------------------- RELATED WORK No. 1184 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0020V1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1184 couldnt find related work element
# -------------------- RELATED WORK No. 1185 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0200V1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1185 couldnt find related work element
# -------------------- RELATED WORK No. 1186 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0200V1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1186 couldnt find related work element
# -------------------- RELATED WORK No. 1187 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0412dV1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1187 couldnt find related work element
# -------------------- RELATED WORK No. 1188 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0412dV1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1188 couldnt find related work element
# -------------------- RELATED WORK No. 1189 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0087V1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1189 couldnt find related work element
# -------------------- RELATED WORK No. 1190 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0087V1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1190 couldnt find related work element
# -------------------- RELATED WORK No. 1191 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0088bV1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1191 couldnt find related work element
# -------------------- RELATED WORK No. 1192 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0088bV1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1192 couldnt find related work element
# -------------------- RELATED WORK No. 1193 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0098bV1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1193 couldnt find related work element
# -------------------- RELATED WORK No. 1194 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0098bV1962v
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1194 couldnt find related work element
# -------------------- RELATED WORK No. 1195 ----------------------
# link: https://vangoghmuseum.nl/en/collection/b0088aV1962r
# 200 ok
# tempPaintFolder exists and JSON does not exists
# this link is weird!!!...
# Operation No. 1195 couldnt find related work element

# %%
print("Number of Data object operations: " + str(counter))
print("Number of Data objects: " + str(len(newData)))
print("Number of completed operations: " + str(len(hasList)))
print("Number of error reports: " + str(len(errList)))
# Out:
# Number of Data object operations: 1307
# Number of Data objects: 1307
# Number of completed operations: 1307
# Number of error reports: 1307

# %%
# actualizo el dataFrame para ver si hay errores
paintsFrame["HAS_RELATEDW"] = hasList
paintsFrame["ERR_RELATEDW"] = errList

# creo una nueva columna para guardar los los diccionarios/JSON dentro del CVS, tambien los guardo en JSON aparte!!!!
paintsFrame["RELATEDW"] = newData

# %%
# guardando los links en TXT y CSV para backup del proceso y control de calidad
galleryFile = "VanGoghGalleryIndex.csv"
dataFolder = "data"

# actualizando archivo original CSV
# si no existe el directorio
if not os.path.exists(dataFolder):
    
    os.makedirs(dataFolder)

# si existe el directorio
else: 
    
    # guardo el DataFrame segun las ultimas actualizaciones
    paintsFrame.to_csv(os.path.join(os.getcwd(), dataFolder, galleryFile), sep = ",", index = False, encoding = "utf-8", mode = "w")

# %%
# chequeo como va el dataframe de procesamiento
paintsFrame.info()
paintsFrame.head()

# %% [markdown]
# ## FIN DE TODO
# termine de sacar toda la informacion relevante de la galeria, cada carpeta deberia tener 4 JSON y una imagen asociada.
#
# Ahora hago un reporte con pandas profiling para ver como me fue

# %%
profile.ProfileReport(paintsFrame)

# %%
# atributos de la busqueda en beatifulsoup
letterTag = "section"
letterAttrs = {"class":"page-unit"}

# formato del diccionario para el JSON de persistencia de la descripcion del elemento
dataDictSchema = {
    "relations": { # diccionario con la lista detallada de las anotaciones de la obra
        "references": list(), # la lista tiene el link y texto/tag asociado
    }
}

# inicializo uuna variable temporal
tempInfoDict = copy.deepcopy(dataDictSchema)

# GET del URL
link = "https://vangoghmuseum.nl/en/collection/b0243V1962"

testLinks = (
    "https://vangoghmuseum.nl/en/collection/b0243V1962",
    "https://vangoghmuseum.nl/en/collection/b8364bV2006",
    "https://vangoghmuseum.nl/en/collection/d0411V1962",
    "https://vangoghmuseum.nl/en/collection/b0243V1962"
)

counter = 1

for link in testLinks:
    
    print("======================= Test data No: " + str(counter) + " ======================")
    linkReq = requests.get(link)

    # si el GET me responde bien con codigo 200
    if linkReq.status_code == 200:

        print("200 ok")
        # parse del cuerpo del elemento de la coleccion
        linkSoup = BeautifulSoup(linkReq.content, "html.parser")

        # si existen las cartas relacionadas se buscan los elementos dentro de la division
        if linkSoup.find("div", attrs = {"id":"info", "class":"set-overview-body has-footer"}) != None:

            print("!= none OK")

            workSoup = linkSoup.find("div", attrs = {"id":"info", "class":"set-overview-body has-footer"})
            # print(workSoup)

            # <ul class="cols mm-cols-2up ml-cols-3up">
            # busco la lista de trabajo relacionado de obras
            if workSoup.find("ul", attrs = {"class":"cols mm-cols-2up ml-cols-3up"}) != None:

                # cols mm-cols-2up ml-cols-3up
                # lista de posibles enlaces externos
                print("if ul!!!")
                linkList = list()

                # si no existe trabajo relacionado
                if len(workSoup.findAll("a")) == 0:

                    jsonInfo = json.dumps(copy.deepcopy(tempInfoDict), ensure_ascii = False, indent = 4)

                    # si no hay errores agrego un mensaje vacio para no danhar el dataframe
                    errList.append(None)
                    hasList.append(bool(True))

                    # agrego el JSON en una columna del dataframe
                    newData.append(jsonInfo)
                    counter += 1
                    print("there is NO related work for this painting, operation No.: " + str(counter))

                elif len(workSoup.findAll("a")) > 0:

                    tempData = workSoup.findAll("a")
                    linkList = list()

                    for rdata in tempData:

                        # recupero el nombre del enlace
                        tempName = None

                        if rdata.find("img", attrs = {"class":"image-lazy"}) != None:

                            tempName = rdata.find("img", attrs = {"class":"image-lazy"}).get("alt")
                            tempName = re.sub(" \s+", "", tempName)
                            tempName = re.sub("\n", "", tempName)

                            # reconstruyo el enlace completo
                            tempLink = urllib.parse.urljoin(paintsRoot, rdata.get("href"))

                            newLink = {"text":tempName, "link":tempLink}
                            linkList.append(copy.deepcopy(newLink))

                    # guardo en el diccionario la lista de enlaces relevantes de la obra.
                    tempInfoDict["relations"]["references"] = copy.deepcopy(linkList)

                    # transformo el dict a JSON.
                    jsonInfo = json.dumps(copy.deepcopy(tempInfoDict), ensure_ascii = False, indent = 4)

    print(tempInfoDict)
    print(jsonInfo)
    counter += 1
